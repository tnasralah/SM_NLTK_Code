# %%
import nltk
import matplotlib

# %%
from nltk.corpus import tudiab

# %%
tudiab.words()
# Out:
# ['The', 'two', 'companies', 'are', 'merging', 'and', ...]

# %%
tudiab_corpus = tudiab.words()

# %%
tudiab_corpus = nltk.Text(word.lower() for word in tudiab_corpus)

# %%
tudiab_corpus
# Out:
# <Text: the two companies are merging and will consolidate...>

# %%
type(tudiab_corpus)
len(tudiab_corpus)
# Out:
# 4558

# %%
stopwords = nltk.corpus.stopwords.words('english')

# %%
tudiab_corpus_noStpW = [word for word in tudiab_corpus if word not in stopwords]

# %%
len(tudiab_corpus_noStpW)
# Out:
# 2501

# %%
tudiab_corpus_noStpW
# Out:
# ['two',
#  'companies',
#  'merging',
#  'consolidate',
#  'apps',
#  'glooko',
#  'sometime',
#  'future',
#  '.',
#  'http',
#  '://',
#  'www',
#  '.',
#  'healthline',
#  '.',
#  'com',
#  '/',
#  'diabetesmine',
#  '/',
#  'glooko',
#  '-',
#  'diasend',
#  '-',
#  'merger',
#  '.',
#  'understand',
#  'diasend',
#  'go',
#  'away',
#  'eventually',
#  '.',
#  'plan',
#  'integrate',
#  'best',
#  'features',
#  'current',
#  'diasend',
#  'mobile',
#  'web',
#  'apps',
#  'future',
#  'versions',
#  'unified',
#  '[',
#  'glooko',
#  ']',
#  'offering',
#  '.',
#  'details',
#  'determined',
#  'coming',
#  'months',
#  'transition',
#  'period',
#  'users',
#  'informed',
#  'well',
#  'advance',
#  'ensure',
#  'timely',
#  'transition',
#  'goodies',
#  'put',
#  'glooko',
#  '.',
#  'glooko',
#  'product',
#  'line',
#  'including',
#  'glookos',
#  'mobile',
#  'web',
#  'applications',
#  'remain',
#  'soon',
#  'become',
#  'greatly',
#  'enhanced',
#  'integration',
# ...

# %%
from nltk.corpus import PlaintextCorpusReader

corpus_root = '/Users/elgayaro/nltk_data/corpora/tudiab'
wordlists = PlaintextCorpusReader(corpus_root, '.*')
type(wordlists)
wordlists.fileids()
