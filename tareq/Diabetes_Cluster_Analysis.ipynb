# %% [markdown]
# [home](http://www.brandonrose.org)

# %% [markdown]
# # Document Clustering with Python

# %% [markdown]
# <img src='header_short.jpg'>
#
# In this guide, I will explain how to cluster a set of documents using Python. My motivating example is to identify the latent structures within the synopses of the top 100 films of all time (per an IMDB list). See [the original post](http://www.brandonrose.org/top100) for a more detailed discussion on the example. This guide covers:
#
# <ul>
# <li> tokenizing and stemming each synopsis
# <li> transforming the corpus into vector space using [tf-idf](http://en.wikipedia.org/wiki/Tf%E2%80%93idf)
# <li> calculating cosine distance between each document as a measure of similarity
# <li> clustering the documents using the [k-means algorithm](http://en.wikipedia.org/wiki/K-means_clustering)
# <li> using [multidimensional scaling](http://en.wikipedia.org/wiki/Multidimensional_scaling) to reduce dimensionality within the corpus
# <li> plotting the clustering output using [matplotlib](http://matplotlib.org/) and [mpld3](http://mpld3.github.io/)
# <li> conducting a hierarchical clustering on the corpus using [Ward clustering](http://en.wikipedia.org/wiki/Ward%27s_method)
# <li> plotting a Ward dendrogram
# <li> topic modeling using [Latent Dirichlet Allocation (LDA)](http://en.wikipedia.org/wiki/Latent_Dirichlet_allocation)
# </ul>

# %% [markdown]
# ## Contents

# %% [markdown]
# <ul>
# <li>[Stopwords, stemming, and tokenization](#Stopwords,-stemming,-and-tokenizing)
# <li>[Tf-idf and document similarity](#Tf-idf-and-document-similarity)
# <li>[K-means clustering](#K-means-clustering)
# <li>[Multidimensional scaling](#Multidimensional-scaling)
# <li>[Visualizing document clusters](#Visualizing-document-clusters)
# <li>[Hierarchical document clustering](#Hierarchical-document-clustering)
# <li>[Latent Dirichlet Allocation (LDA)](#Latent-Dirichlet-Allocation)
# </ul>

# %% [markdown]
# But first, I import everything I am going to need up front

# %%
import numpy as np
import pandas as pd
import nltk
from bs4 import BeautifulSoup
import re
import os
import codecs
from sklearn import feature_extraction
import mpld3
import pickle

# %%
save_clean_lines = open("clean_diabApp.pickle", "rb")
paras = pickle.load(save_clean_lines)
save_clean_lines.close()

paras
# Out:
# ['blackberry url heremaybe url specific good luckpost work myglucohealth glucometer blackberry fda approved bluetooth meter take reading automatically phone web granted viewing right health care provider check level text recommendation feature opinion integrated notification offer test receive text message phone question step correct situation reply minute start send message worker working hour wife evening message support member prevented hospitalcheck url based company gen diabetic older thread wrote article precisely topic thing tech column url thought comment question management blackberry user',
#  'putting blog friend recently diagnosed gadget smart phone plain dinky flip phone case emergency thing smart device apps smart device asks hoping favorite apps inspiration friend gee phone constantly thought thing carelink enlite data url people developing pwd basically care logbook wise printout pretty good love changed management huge fan android iphone tech savvy talking helpful wow make sound benefit word point familiar apps flip phone make phone call fell lap question check smart phone free hmmmmm research today iphone gadget apple logo phone large screen compared flip phone thumb lot bought ebook reader scroll function work sold picked dawned thing heard people talking apps thought take phone link gave url log basically online version click free trial basic free free version long time satisfied bought version advantage version print log book send endo mandatory advantage happy pay check insulin pen insulin pump called rapid calc good link url track pump including insulin board iob check figwee swisschocolate mdi mysugr calculate iob thing work event pump mdi sound nice idea mysugr calculate iob techy flip phone transmitter receiver mail today saturday hooked buying iphone wanted bought greater accuracy guy talking apps enthusiasm buy fancy phone btw iphone lot funky gadget million thing talk monitor bgs trend news weather youtube instant message calculator contact info reminder list calendar clock timer camera basic thing iphone literally thousand thousand specialized apps buy free interested diabetic changed life creating mobile started thing learning reading nutrition information package people time diabetic read information important information developing help creating grocery list purchasing grocery store apps electronic version pen paper theory diabetic advertise obtain beta tester make people life start company main mission people respectfullyashley cribb founder lythouse lab llc lythouselabs',
#  'iphone android apps healthline click link suggestion',
#  'start logging blood glucose reading endo email weekly wondering couple glucose buddy simplicity limited chart layout complex junk enter food water exercise insulin ect blood glucose logging pay android good track pretty simple gonna shot interested mysugr downloaded interesting briefly loathe logging rely pump cgm track stuff worked lose food effort shave tracking macronutrient ratio yell pigging work myfitnesspal food increment work pay version purport offer logging cheap buy loathe logging meter touch verio sync touch reveal receives result meter bluetooth log automatically send blood glucose value doctor pump cgm combo send data stored device doctor glooko great syncs popular meter decent food diary count carbs feature faxing report joselin glooko issue omnipod supposedly working blueloop mycareconnect interface friendly major benefit automatically alert wife tested alert text email configurable peace mind glucose buddy mysugr month easy kind fun mysugr junior version kid track bgs developed apps glucosurfer org project calculates insulin board modern pump bolus calculator documentation menstrual cycle included anonymity free financed donation strong project analysis sharing capability',
#  'largest problem finding combine glucose reading insulin dos carb count thing exercise dexcom cgm show show clarity read title thread prepared snappy answer apps constructive stay post downloaded paid good money apps called track ability thing mentioned android version iphone version heard mention called glucosurfer dexcom event insulin exercise health carbs square trend line turning phone sideways event swiping finger point insulin food event distinct shape circle triangle user distinguish glance mynetdiary great tracking great built food database food box scanned upc code apps ipad phone mysugar iphone visit project url create account download glucosurfer testing free anonymously collect personal information email address support android iphone window phone download love testing onetouch reveal free url week year finally giving paper logbook designed sync bluetooth verio sync meter meter easy enter insulin carbs exercise logbook display good onetouch reveal month timesaver verio flex meter bluetooth data online account manually enter data log holger glucosurfer sync meter sync convenient end number blood glucose value influencing factor high correction log dosage experienced low treated glucose log gram note excercise carbs log carbs excercise level mindset opinion meter log age data read cable reading tool age doctor meter data information thing specific moment medical team handled specific challenge feedback decided digit enter worth hassle bluetooth syncing digit dosage calculation gram carbs plan eat estimated insulin board valuable information synced conveniently bluetooth understand thinking contradicts mindset holger reply agree collection meter reading remark attached useless looked logging event surrounding reading current meter send mysugr phone accessible web mysugr bored fun comment battery life verio flex bluetooth lifescan rechargeable battery aaa battery recharge mention including exercise including reading fitbit activity monitorif wanting enter reading exercise free pretty flexible log entry food carbohydrate calculates active insulin board track weight medication insulin send report doctor email host thing verio flex month replace battery miss rechargeability backlit screen port light verio bluetooth pretty awesome compromised great count carbs add manually battery died called lifescan month short time battery life year replacing meter ended flex rechargeable added suggestion file people upgrade verio flex verio flex rechargeable backlit bluetooth equipped hope bathyscaph tudiab mynetdiary latest opinion latest mynetdiary max improvement planning buy cell phone order understand ability enter tracking issue time decide enter temperature time day progress enter comment blood sugar reading basically place enter comment entry wish makethen plan fitbit encourage walking set work tandem choose phablet screen tablet aspect important people manage small screen thing magnifier ultrasmart blood monitor cell phone feasible janina extensively tracking version thoughsgood luck',
#  'guy work tidepool released product called blip bunch graph tool analyze blood sugar medtronic pump enlite cgm graph carelink graph easier change date stuff data pump cgms meter jazzed thought wait product nutshell make note ate blood sugar handled feel remember sitting restaurant eat meal love remember squared time managed spike check url note apple android make note day sync data heard founder howard speak jdrf research summit weekend awesome home set beta testing nutshell super cool blogged blip experience night url forward hearing experience remember chat room excited interview url year ago watch check howard interview mariebmollyschreiber read nutshell experience jealous beta listi appointment endo bring tidepool graph time uploaded data huge fan thing integrating multiple data source produce pretty nifty graph dexcom cgm carelink data minimed contournext meter upload screenshot gave minute spinny ball joy reason work site fwiw daily view upload section show cgm small dot punctuated big fingersticks bolus graph distinguishes manual bolus calculator basal show suspended pump shower temp basal anticipation evening bike ride stacked synched time day scan signal track glance intuitive display imo sounded interesting work chrome browser reticent upload health data site wait independent private platform totally agree intuitive display drbb love drag thing change timeframes hurt load carelink report day nice flat cgm line day customize target range bit pic week including note blip cool exercise context day hooked beta testing account nutshell time today post picture work upload carelink data scratch upload picture spinny wheel joy time charm ended url inserted link finally worked site happy uploading file server heard talk jdrf conference march immediately started tidepool blip love dexcom sensor reading carelink material site great drbb maureenh taryn mollyschreiber marieb feedback coming love hear experience blip tidepool uploader help make nutshell beta hope tidepool booth bay area summit attended yesterday university california san francisco medical center awesome hippa compliant forward dexcom charted anima pump information month thought follow view nutshell fun playing making note blip note taking insulin prebolusing percentage dual wave info eventually tracked nutshell perfect tool figuring tackle favorite meal tricky high fat require insulin strategy started blip tidepool updater love free url recommend taking insulin device upload data fromdexcomg mac windowsinsuletomnipod mac windowstandemtslim tflex tslim tslim mac windowsmedtronicparadigm enlite sensor mac window carelink login info pull data thereanimasping vibe mac windowsbayercontour contour usb contour link contour usb mac windowsabbottprecision xtra freestyle lite freedom lite windowsonetouchverioiq mac windowsi blip run google chrome browser chrome computer free url data window set chart amazingly endocrinologist think tight control low improve hour chart noticed pattern high late afternoon drop basal rate tweaked basal tiny bit window obvious pump setting cgm reading tidepool blip note phone fast easy ate pizza tubing kinked blip note automagically drop note chart reading time platform open source data remain accessible locked manufacturer web page criticismtidepool customize chart target range target range time window organize display info differently way chart handy ideal glad finally wrangled madness separate manufacturer sequestering data separate apps place huge',
#  'site endorse analysis software recommend feel good ultimate goal predictive statistic exist analysis pull data basal bolus testing compare exist minimed carelink upload software super analytical help identify trend time period number recently usb upload device buy minimed educator extra happy discovering graph meter display plugged web based site diasend diasend carelink analyze pump data history mm5 pump cgm pretty good job predicting high low event shortly happen extra time correct drift pump target range stop high low reduces severity prob injected vein rossen barbanov google android market import spreadsheet calculates insulin board statistic including standard deviation program ratio sensitivity update couple day founder glucosurfer project analysis tool offer valuablethe agp diagram show hour day highest volatility reminds development aware higher frequency dawn phenomenon put finger hurt inoffensive trend show relation category high high normal low developed month month act early warning tool sooner blood test pat shoulder recent improvement brain bag jellybeans smarties carry eat turn pump run high pretty tight standard couple day row turning pump medtronic carelink software super lazy talking online buddy evening suggested device sound alley',
#  'group people interested related smart phone web based application development giving feedback developer make people agreatchance folk working improve life great people joining inas emily mentioned application modd mobile detective feel free test user account create minute question feel free post comment reach personally lena mamykinadbmi columbia forward hearing everybodythank shared experience feedback mobile detective learned making address comment love hear time application url experience create account research project mean share user information lena allquick announcement released version application problem solving number feature notably possibility recommendation leave comment experience goal feel free create account url hear experience lena',
#  'nan called modd advice sickness plan pointless sick concerned proper nutrition busy throw ate brat aka diabetic unfriendly diet khrtmodd stand mobile detective mobile play create account interaction user phone feel free good point sickness plan advice comment research team comingthank lena lena test set account fictitious blood sugar reading tomorrow day pop check frequently consistently alarm alert turned omnipod pump pdm extremely beep weary hope cell phone start yelling test blood sugar testing blood sugar implies fail prefer check blood sugar claregreat creating account test account generally speaking modd sends reminder day optional choose set alert check blood glucose time day sound turn reminder click page edit profile password uncheck usage reminder check box main number setting goal day worth number frequency important click number average row table follow step love hear good catch checking testing lena completed day entry entered bunch spurious number response turned reminder start thing day graph bit dexcom day trend chart easy read interpret low number breakfast reading test work setting goal target range modified people perfectly happy meal prefer set target chose set goal breakfast reading disappointed choice offered increased dicreased spelled insulin increase dicrease discussing healthcare team discus time change phone ended putting suggestion presented applied situation doubt make general generalized suggest running spell check launching clairthank comment interesting point target changing target range determine target range stable change time timein term dicreased catch professional copy editor content health communication expert guess slipped crack corrected recommendation hoping team educator discussion educator clinician agree good general recommendation add general list recommendation recommendation thought interesting appropriatethanks comment lena read recommendation novice year rule standard treatment hypoglycemia carbs started counted suggested check glucose tablet figure carbs contained amusing hard pressed glucose tablet contained gram carbs gram called diachieve online problem rule consideration hypoglycemic patient treat hypo differently treat gram carbs increase blood sugar point glucose tablet increase point treat gram carbs increase point focus avoiding roller coaster treating hypoglycemia thing amusing goal section researching breakfast low suggestion drink alcohol suppose potential reason post breakfast hypoglycemia gawd wait noon target blood sugar insulin pump target range meal meal stable change set approval endo cde recommendation protein meal avoid drop started putting peanut butter toast morning smoothed post breakfast blood sugar basically good average pwd stick ada guideline access cde endos thing work improve control graphic image blood sugar necessarily day accurately represent trend decision making day worth data cgm making care clare clareah apology confusion misspelled annoying insightful comment year surprising recommendation glad hear generally application targeting individual experienced knowledgable lot learn recommend member tudiabetes make keeping track meal thatas additional note preparing version application social feature profile comment make friend tudiabetes couple week love wellthank lena houston problem lenai entering data modd couple week finally set goal inventing bunch breakfast low suggested adding protein breakfast make sense digested slowly smooth drop added protein breakfast thing smoothed mark problem solved breakfast blood sugar average normal solve problem high breakfast solve problem low breakfast guess day average set goal fix low report fixed goal average blood sugar lower helpful guess single day enter data time gather take day glucose average trend problem approach change behavior insulin dose diet exercise combination thing take longer day ass change routine adding protein breakfast changing pump setting basal rate ratio week declaring success failu ...
#  'vienna austria startup mysugr awarded million medium budget germany largest mass medium company mysugr place venture pitch day vpd competition focusing health fitness company mysugr cmo anton kittelberger explained company stay true mission making suck contest held noah conference berlin june featured familiar name runtastic meedoc place winner withings pitch anton explain mysugr make people happier healthier digital health solution make feel good taking care anton kittelberger cmo mysugr people ignore risktheir health prize improve countless life fear ofdiabetes therapy mysugr world idea real life destigmatizeit prosiebensat groupthe prosiebensat group largest independent medium corporation europe germany largest internet video company reach million household day station germany austria switzerland info url mysugrfounded people mysugr creates digital health solution people product characterized intelligent combination design technology medical expertise focused mysugr logbook registered user worldwide info url url johnson scott johnsonmysugr',
#  'group researcher department biomedical informatics columbia university developed application management application combination interactive website text message application individual track blood glucose reading based reading application individual recognize problematic pattern blood glucose behavior contribute pattern make personalized recommendation management behavior interested eligible study chance application make discovery hope study design tool management interested taking study link connect study website register stress participation voluntary membership tudiabetes community affected choice study detectiveif additional question contactlena mamykina assistant professor columbia university omcumc columbia study approved tudiabetes administration team',
#  'allthe creator called docto asked feedback docto purport knowledge based designed deliver medical advice based user distinct biometrics docto docto store mailing askdocto member tudiabetes test share opinion post discussion thread happy testing email heard huh touch clare emily clare amir developer docto talked url',
#  'good enter bloodsugar thing mysugr fun url pump track data pump computer waist recently posted basically question url holger glucosurfer insulet screwed shipment injecting holiday wait shipment pod arrive today simply pump actual pump bolus wizard stuff calculating correction carb bolus amount track iob biggest win make true pump mdi reality shocked competing apps track iob bolus wizard assist glucosurfer complete ton additional helpful feature finally purchasing glucosurfer android help support holger glucosurfer site encourage support contributes lot tud additional donation directly glucosurfer site encouraged',
#  'american association educator created called goal tracker aim people identify achieve health related goal healthy eating remembering medication coping stress free download android iphone search store aade goal tracker chance post comment address aspect taking care person diabetic physical health mental health taking time meditation diabetic benefiting part explore initial thought love reminds check thing view goal expedient page great everyday',
#  'sanofi bgstar agamatrix rebranded software compatible window install bit window installation roll sidiary url commercial software euro yearly download diabetic device data bgstar requires bgstar software installed discovered sidiary requires cable driver cable usual usb cable silabs chip link silabs doc driver download downloaded driver link click tool tab file cpxvcpwindows zip unzipped running exe installer modified slabvcp inf file adding identification string sanofi cable usbvidf pidaaaa window ultimate bit download bgstar reading merge glucometer brand sync online android sidiary good attach modified inf file replace original running exe install window recognise driver valid signed driver changed file remember trust driver exists linux osx software implement bgstar agamatrix protocol download slabvcp inf technology read entire post understand word starting talking meter talking software meter sanofi bgstar agamatrix url run window bit modified driver software url window bit user download analyze reading sidiary told checked method add modified driver list supported meter link garidan workaround install bgstar software bit window computer problem relates bit device driver bgstar setup wizard ended prematurely error standard compatibility setting run admin',
#  'called diary sinple easy mail log csv format open excel minor formatting send doctor love space track protein fat tag formula easy enter symlin note application author mention work progress adding feature feedback warrant make nan nan',
#  'triple complete happy announce called glucosurfer published apple store release offer apps iphone ipod android window phone manage glucosurfer diary feature insulin pump integrated bolus wizard calculation insulin board iob mdi user feature hope make daily management task easier visit website url group detail downloaded regardsholgerand team glucosurfer org today free edition glucosurfer iphone published store edition feature version test long buy experience negative glucosurfer group',
#  'lot glucose tracking info logging website accompanying iphone apps make entering data easier preferably necessarily free accompanying blackberry apps glucosurfer project online solution glucose log test blackberry simulator worked idea glucosurfer feel create link url browser line break url link user password admit minimalistic approach feedback highly appreciated send comment interesting solution slow daily prefer browser display small time load page zoom kind time consuming annoying browser understand curiosity needed zoom glucosurfer page open link kari blackberry good tracking ended buying itouch iphone apps work lack ability add info needed stuck duplicating info hard copy endo prefers hard copy versus downloading meter reading guess stuck keeping track fashion good luck search great shout kari necesarily database online store data blackberry device apps url free written nokian working blackberry url free data saved csv format send mail download open practically portable pda mobile device desktop computerif data stored online profile solution purposed holger purpose free version sugarstats url support opera mini install blackberry good luck finding solution sweetjimmy zoom page issue issue website developer web site include specific meta tag control zooming adjustment hope issue beautiful looked irecordit',
#  'started searching enables record track info relevant management track enter time day insulin dose carbs specific food eat important glycemic index food mysteriously affect differently5 exercise note illness stressi phone apple macbook air fine suggestion greatly appreciated lose midst switching myfitnesspal started hanging online exercise group fun share separately pump cgm job logging glucosurfer graphic representation thing timeline people scott johnson mysugr good result briefly hyper testing huge hassle stuff log mysugr iphone easy kind fun group url discussion apps url include integrate mentioned blackberry guy download hope wrong hand join iphone universe track monitor link glucosurfer org nice job integrating checked neat foodwise total sucker barcode scanning holger member communicative issue fixed glooko promise cool startup graps data meter forward android url record info note open spreadsheet excel organized column completely flexible take time enter info figure mysterious pattern happy recording insulin meter touch ultra smart remember enter insulin insulin usage statistic watch change tdd bolus basal ratio fact meter record listed carb exercise note time enter number specific food eaten',
#  'everyonenew forum tudiabetes market manage minimum level tracked doctor food exercise great choose love hate tia glooko month visit endo visit receptionist asked meter pdm omnipod user proceeded upload reading month uploaded phone glooko admit checked apps trend graph statistic post visit mac upload data android user easier time techno savvy glad tudiabetes amazing place lot love support great open discussion topic work mysugr opinion totally biased happy answer question decide great piece advice heard recently adam brown diatribe great place good information acronym test download feel good notr read review learn lot company review toggle switch version version review reset time update released beautiful thing stick worry hope help great apps feel overwhelming problem righttake care mysugr imho muncapher tudiabetesall apps named great hard wrong advice feel big drop fan started march loved join drop team happy walk drop answer question people including love easy log everythingif decide drop love hear rachel mysugr dexcom mysugr synchronize dexcom info apple health iphone cgm trace graph hour delay realtime dexcom information dexcom apps access realtime reading limited hour delay screenshot image good admit mysugr love monster cute diet exercise controlled help log glucose reading carb intake love reminder time forgetting test hour eat busy mom teacher mind thing recently switched form android iphone nice added feature iphone importer camera read meter import logbook create report emailed half feature insulin cgm gave great advice mysugr logbook free paid pro version pay pro free version invested pro feature loved earning point entry tame monster fun motivates good luck wanting track manage pump rapidcalc calculate insulin dos track shot love suggestion test work mysugr year bought paid version track include food exercise stressed sick photo option paid version picture meal guessing carb count refer wrong figure future eating guesstimate lot depends mobile platform computer platform manage number apps logging management greater iphone ipad android forbid window phone number apps require constant cellular connection iphone work ipadnot mobile apps export data printed managed computer export standard format xml pdf viewed printed xml varies device device manipulated important apps export mac forbid running linux apps manage food carbs calorie protein consumption saturated fat consumption selection micronutrient including sodium apps manage blood pressure needed apps pwd eat meal day snack period day shift work meal schedule day grazing meal based diet pigeonhole food meal setting mean ontrack pretty choice enter manually input glucometer sphygmomanometer time played desktop version microsoft healthvault take gyration sort information feel mysugr league user experience intuitive fun fee cracked code making suck bolus calculator wary fda cleared accuchek work insulin soaking portion prescription code apps dosing recommendation intentioned developed limited testing largely limited small group hesitant rely insulin dosing decision tmana info hoping post smart careful dosing apps tool carefully programmed daily management rapidcalc lifesaver struggle remember shot insulin ratio time day willy nilly carefully input information update account insulin attention reliable read glooko diasend working started omnipod glooko glooko communicate dexcom apps track insulin boardi mdi program hour bolus tracked math enter note section bolus remind meter built bolus calculator accu chek connect doctor prescription unlock calculating iob meter automatically syncs quickly reliably phone mysugr sync roche downloaded pump mysugr bolus calculator approved europe time thing fda kill google bolus calculator meter bolus calculator idea integrated service gary scheiner excel file bolus calculator iob calculator url integrated service gary scheiner excel file bolus calculator iob calculator url spreadsheet interesting iob hour jive experience novolog excep ...
#  'starting summer platform tudiabetes run start undergoing update make site easier simplify site layout improve work multiple device connection upcoming platform tuanalyze longer compatible tudiabetes coincides end year grant center disease control cdc develop tuanalyze taking july offer tremendous community tudiabetes org estudiabetes org participation research member tudiabetes community participated project donated data centerpiece peer reviewed scientific paper value care pattern hypoglycemia numerous abstract conference presentation forward working hand foundation identify way tudiabetes community contribute valuable cutting edge research information detail decommissioning tuanalyze additional question comment email study team tuanalyzechip org faqswhat happen data tuanalyzeafter july data entered tuanalyze including value survey response longer viewable tudiabetes download entered data secure server boston childrens hospital shut server data remain secureyes tuanalyze server shut data set maintained secure password protected computer boston childrens hospital accessible tuanalyze study team data enter tuanalyze stored randomized numberonce destroy link number identity tudiabetes effectively anonymizing data set chosen display acs entered tuanalyze tudiabetes profilewill upno data entered tuanalyze longer visible tudiabetes org update data downyes encourage add latest tuanalyze july final data set tudiabetes member complete survey complete edit survey completed result tuanalyze projectbelow set link result presented tuanalyze update community additional paper published early result blog poststhe state tuanalyze january flu vaccination tuanalyze participant compared national surveysearly result hypoglycemia surveyearly result device surveyjournal articlessharing data public health research member international online social networksurveillance online social network ass population level health status healthcare qualityparticipatory surveillance hypoglycemia harm online social network man total bummer love map scorecard recommend make source code github geek time motivation revive project api changed helpful specific problem habe solved integrate ning tudiabetes dhf payed project grand copyright source code problem',
#  'darios management solution incorporates regionally localized food database manage sugar levelscaesarea israel april labstyle innovation corp otcqbdrio developer dario management solution today announced partnership world leading global nutrition data application fatsecret fatsecret platform integrated darios powerful management software application deliver localized nutrition datasets generic food branded product restaurant item empower people easily track manage food intake resulting blood sugar insulin level dario user labstyles initial market location united kingdom italy zealand benefit immediately labstyle forward helping people thrive dario reach location europe year pending regulatory approval north america fatsecret dario management regionally localized food database tool help people automatically log sugar range food language country world fatsecret nutritional information carbohydrate fat content broad range food type information combined darios tool expected showing user food consumed affect individual fatsecret delighted partner dario seamlessly integrate world food nutrition tool dario empowering people charge health manage lenny moses founder fatsecret logging managing blood sugar level critical activity manage calculate required insulin treatment daily challenge people explained erez raphael president chief executive officer labstyle excited partner fatsecret add extensive food information database offering providing access critical food information user making easier people manage erez continued seeking make dario comprehensive added management solution initial feedback dario initial roll promising fatsecret travelling easier carbohydrate fat content basic local food bread coffee restaurant meal vary world dario people local food familiar impact sugar level dario user simply log blood sugar level recorded small stylish dario glucose meter plug directly smartphone user glucose meter manually insert blood sugar level recorded existing device simple prompt user note food eaten fatsecret library recent physical activity mood stress level dario automatically log data people sugar change manage condition treatment labstyle innovationslabstyle innovation corp otcqbdrio develops commercializes patent pending technology providing consumer laboratory testing capability smart mobile device labstyle flagship product dario personalized smart meter dario received mark certification september began world rollout select country december labstyle filed premarket notification application food drug administration fda dario smart meter dario blood glucose monitoring december labstyle pursuing patent application multiple area covering specific process related blood glucose level measurement general method rapid test body fluid mobile device cloud based service information url url note forward statementsthis news release statement representative partner labstyle innovation corp company related thereto forward statement meaning private security litigation reform act statement statement historical fact deemed forward statement limiting generality foregoing word plan project potential seek expect anticipate intend estimate continue intended identify forward statement reader cautioned important factor affect company actual result result differ materially forward statement news release factor affect company result include limited regulatory approval product demand market acceptance impact competitive product price product development commercialization technological difficulty success failure negotiation trade legal social economic risk risk adequacy existing cash resource additional factor contribute difference company actual result forward statement include limited risk discussed company filing security exchange commission reader cautioned actual result including limitation result integration fatsecret dario platform market acceptance company regulatory plan dario generally differ significantly set forward statement company undertakes ...
#  'exciting running current nightly build xdrip code real time development high risk software bug problem ability android wear smartwatch communicate bluetooth directly phone running loop working fine running minute phone shut long call text watch dutifully collecting reading exciting watch wrist consistently gadget including dexcom receiver mistake time time leaving house forgetting phone saturday running errand supposedly data syncs phone watch phone connect future work minute turn phone dexcom android wear smartwatch version xdrip downloading installing latest nightly build google drive repository gap reading installing build playing setting working report dave latest patient sentiment pushing commercial timeline direction important forward update learn software beta ready general release awesome post dave specific bug wondering data watch hold gap comprehension simple term cost dave ordered watch amazon house jazzed upgraded voodoo mail possibility android iphone love idea transmit direct watch phone work android wear watch price varies expensive depending style android device pair uploader canada jen canada original share comprehension simple term cost dave ordered watch amazon house jazzed upgraded voodoo mail possibility android iphone love idea transmit direct watch phone favor sam cost price equipment hold bit software ready newest feature allowing direct watch reading work buggy unreliable released community beta playing code developed checked developer proof concept real cool lose connection problem earlier version xdrip phone resolved doubt connection reliability issue resolved watch connection sony smartwatch standalone mode time carry android phone watch essentially run xdrip phone stripped version specific watch watch bgs synced phone device connecting download value export uploaded nightscout connected phone great hear developed google android guy code developer kid instilled hear nice application apple store google play store smart android win user sony smartwatch standalone mode time carry android phone watch essentially run xdrip phone stripped version specific watch watch bgs synced phone device connecting download value export uploaded nightscout connected phone stripped public xdrip couple month fairly happy result switched xdrip regular xdrip working fine samsung galaxy active matter sony smartwatch standalone mode time carry android phone watch essentially run xdrip phone stripped version specific watch watch bgs synced phone device connecting download value export uploaded nightscout connected phone stripped public xdrip couple month fairly happy result switched xdrip regular xdrip working fine samsung galaxy active matter stripped referring simply xdrip watchface style installed xdrip watchface simple include extra feature xdrip displaying treatment projection watchface pretty dexcom receiver display interactive display graph current data bad news work setup galaxy edge phone huawei android wear watch good functionality installed steadily deteriorates day completely nonfunctional watch connected phone oddly galaxy gear smartwatch phone bluetooth interfering xdrip taking reading phone android wear fixed big xdrip fan actively discussing issue gitter chat developer pull source build debug problem mind people problem gitter discussion looked huawei watch unique watch problem discourage public open source developed volunteer engineer xdrip xdrip similar feature treatment taking insulin carbs standalone feature glad hear innovation garmin fenix receive notification bluetooth pull cgm data nightscout cloud based repository cgm data simply work drain battery quickly notification dexcom low urgent low helpful actual number direction arrow hope day post pic setting send data directly android watch dave chance figured send signal directly android wear phone phone range asus zenwatch worked couple time stay consistently connected bluetooth carry phone work smartwatch advice greatly appreciated dave chance figured ...
#  'clinic big center working resource electronic medium application carb counting suggestion talked calorie king folk creating time user application android phone pad suggestion nan wished calorie king iphone good apps calorie counter work great android phone ipad response excellent link livestrong site decent carb info prefer calorie king calorie king connected tremendous myfitnesspal technically calorie exercise tracker carb information amy checking thread somone amazing nan calorie king smart phone internet data access web site free carbs calorie count date real time web based fast food calorie counter droid eating sanofi gomeals based calorie king varying degree review nan free android gomeals incorporates calorie king database sponsored sanofi mentioned free fresh food restaurant data daughter iphone separate apps installed work cost dollar gladly pay apps information thankful guy writing thought person written track guy correct nice email data doctor reviewed doctor order big picture situation phone driod work iphone david father teenager make life caniphone url url feel late conversation checked apps run apps include carb counting free fooducate simple grade food eating high school barcode scanner limited food database personalize carbs ingest day net carbs adding fiber pretty decent time carb calorie counting user myfitnesspal detailed great personalization option connect friend chose barcode scanner myfitnesspal largest food database calorie counting market online website computer tracking layout myfitnesspal confusing option personalize overwhelming option offer personally wanted chose lose personally favorite kind combination fooducate myfitnesspal simple layout user friendly depth information tracking healthy lose win book issue food database large barcode scanner included light phone sens darkness screen overview day tracking carbs fat protein chose monitor online website computer tracking simple review calorie carb counting apps personally android iphone google search bring website simply copying pasting information carb insulin dosage counter mysugr amazing interactive fun logging sugar daily battle monster slowly control healthy choice website free long message hope help carb counting query wolfram alpha engine knowledge engine data gathered website gathered verified source start query carbs gram food examplescarbs mangocarbs burger king whopper friescarbs subway',
#  'recommendation android apps diabetic log food journal enter actual food item description carbs calorie question pal awesome great logging feature report syncs secure website grant doctor access generate print chart report pdf geek chart graph mysugr easy fun forgot provide linkdiabetes pal awesome check initially apps looked great unavailable android',
#  'desperate healthengage software mac software mac input reading computer create graph chart doctor internet insane software similar idea mac software read onetouch ultrasmart meter insurance company cover touch stripsemblemhealth stop exists solution touch ultra smart meter uploaded diasend diasend platform agnostic web based site produce nice chart integrates insulin pump continuous glucose monitor data diasend free data stored program meter reading stored date time stamp good luck touch ultra smart store record diasend work',
#  'mytherapy germany leading people manage medication taking mytherapy international level mytherapy uniquely combine medication reminder health tracking reliably reminds med active track vitals work mytherapy translates therapy simple list daily goal checking task peace mind time mytherapys built health journal summarizes medication intake health related information mytherapy free charge google play store apple store feature glance medication reminder patient disease med summary blood pressure blood sugar tracking wellbeing symptom monthly health report friend family motivate med free charge google play store url store url positive effect medication adherence scientifically proven charit berlin registration needed data protection hand individual based information party homepage url',
# ...
#  'developing helper team helparound thousand stranger stepping learned fear user cope realize imperative hold people trust time distress built alert simple pressing big red button shaking phone alert conference people trust designed community living caring risk experiencing physical emotional distress asthma attack severe allergic reaction addiction relapse panic attack dementia related confusion crohn flare ups list moment fine motor skill deteriorate thinking muddled make difficult properly navigate smartphone easy shake phone send alert alert download android mobile phone post approved hand foundation tudiabetes administrative staff imagine advanced dementia midst confusion clarity mind shake phone geez low bad dementia apps phone phone thought finding carbs sitting low faint feeling brilliant idea smartwatch user needed remind drink water respond watch hangout message frickin remind drink water sigh kid overload mind twitter tweeting ado dad smart alert deal smart phone convinced buy week returned remember operate concentrate phone function ignore feature brain deal dementia age memory problem abstraction smart phone fine dumb phone laptop complex task replacing component dlp dementia apps smartphone hard imagine agree mum lost banking ability forced passbook account card atm major problem buy electric kettle work switch slightly place dementia preferential losing physical ability imagine imprisoned wheelchair keen mind shake smartphone time life needed handle low helped moment alert zombie coffeeshop sat began people noticed figure wrong managed hard lot easier access emergency contact speak moment lucky people worked coffeeshop knew',
ysis level guess reason blown software sort take edge cliff decrease report tomorrow glucose buddy food activity medtronics site upload export pump meter data combine send cde doctor step love export site reference cde mac ipad problem apps fda ipod iphone approved software platform doubt ipod consist ipod data viewing device layer risk disclaimer alleged meter agamatrix plugged ipod basically run attachment ipod data viewing device protect people realize risk point stifiling creative integrated solution make life easier stuff limbo day inventive past year avalible make good point jake apps iphone apps stuck log life favourite term data entry fewest tap enter data glucose buddy good free entering data bit cumbersome pilot data analysis integration food database desktop ultimately recording reading note blog livejournal stick help remain track number broken statistic graph quick convenient data meter pump add note needed switching onetouch ping pump hoping meter remote serve purpose online thing iphone great wise carbohydrate information nan newly diagnosed year daughter tech savy ipod touch called pilot log blood glucose carb count insulin trend bar graph stats send desk print out like cost dollar dissapointment cde read vertical horizontal record party make cable compatible bit window remember install partial solution install window virtual machine window bit piece puzzle compatible cable risk engineering company make cable differentbetter usb serial converter based ftdi chipset crappy prolific lifescan slightly expensive lifescans cable make freestyle cable url trouble report send cde younlike pilot free program good additional fee desktop versionthanks advance dan love hear people pilot added store imac nice desktop iphone version good comment free droid called ontrack customize quick add feature glucose food excercise med weight pulse hbac body fat edit info stored report graph customize card restore lost data export excel email research apps apps hear epic fail today fancy ontrack thinking interesting home work txt mrsacidrock turned phone morning data spaced work cut record keeping touch ultra meter bit gateway series mach ...
#  'published healthlineaugust national fact sheet percent american staggering time prediabetics fortunately managed combination proper medical care care word regular doctor visit patient diligent monitoring blood sugar taking medication insulin prescribed physician diet exercise regimen overwhelming apps developed manage favorite supplement existing physician supervised care click icon learn totally window phone ecosystem kind sad platform glucosurfer android testing phase latest version offline capability vizualization current phase menstrual cycle proud ontrack android recently started glucosurfer great entering past data bolus wizard default setting ratio correctly predicted high low experienced added bonus enter data phone browser share result live endo personally wave sense logbook meal glucose buddy bit interface user friendly wave sense intuitive love trend chart feature sanofi ibgstar download free meter meal carb counting comprehensive easy require internet score android free edition switch google play support project thinking phone smart phone hear people opinion apps ibgstar tracker motivational problem mysugr cool logfrog manager patient ibgstar wanna pay sign problem send print data table overlooking advice appreciated tool android device called advanced insulin advisor insulin bolus calculator take account active insulin remaining body set carbohydrate directly predefined meal database picture daily read ifrdesign free aia advisor helpful']

# %% [markdown]
# For the purposes of this walkthrough, imagine that I have 2 primary lists:
#   - 'titles': the titles of the films in their rank order
#   - 'synopses': the synopses of the films matched to the 'titles' order
#
#
# In the full workbook that I posted to github you can walk through the import of these lists, but for brevity just keep in mind that for the rest of this walk-through I will focus on using these two lists. Of primary importance is the 'synopses' list; 'titles' is mostly used for labeling purposes.

# %% [markdown]
# # Stopwords, stemming, and tokenizing

# %%
# #import three lists: titles, links and wikipedia synopses
# titles = open('title_list.txt').read().split('\n')
# #ensures that only the first 100 are read in
# titles = titles[:100]

# links = open('link_list_imdb.txt').read().split('\n')
# links = links[:100]

# synopses_wiki = open('synopses_list_wiki.txt',encoding="utf8").read().split('\n BREAKS HERE')
# synopses_wiki = synopses_wiki[:100]

# synopses_clean_wiki = []
# for text in synopses_wiki:
#     text = BeautifulSoup(text, 'html.parser').getText()
#     #strips html formatting and converts to unicode
#     synopses_clean_wiki.append(text)

# synopses_wiki = synopses_clean_wiki
    
    
# genres = open('genres_list.txt').read().split('\n')
# genres = genres[:100]

# print(str(len(titles)) + ' titles')
# print(str(len(links)) + ' links')
# print(str(len(synopses_wiki)) + ' synopses')
# print(str(len(genres)) + ' genres')

# %%
# synopses_imdb = open('synopses_list_imdb.txt').read().split('\n BREAKS HERE')
# synopses_imdb = synopses_imdb[:100]

# synopses_clean_imdb = []

# for text in synopses_imdb:
#     text = BeautifulSoup(text, 'html.parser').getText()
#     #strips html formatting and converts to unicode
#     synopses_clean_imdb.append(text)

# synopses_imdb = synopses_clean_imdb

# %%
synopses = paras

# for i in range(len(synopses_wiki)):
#     item = synopses_wiki[i] + synopses_imdb[i]
#     synopses.append(item)
synopses
# Out:
# ['blackberry url heremaybe url specific good luckpost work myglucohealth glucometer blackberry fda approved bluetooth meter take reading automatically phone web granted viewing right health care provider check level text recommendation feature opinion integrated notification offer test receive text message phone question step correct situation reply minute start send message worker working hour wife evening message support member prevented hospitalcheck url based company gen diabetic older thread wrote article precisely topic thing tech column url thought comment question management blackberry user',
#  'putting blog friend recently diagnosed gadget smart phone plain dinky flip phone case emergency thing smart device apps smart device asks hoping favorite apps inspiration friend gee phone constantly thought thing carelink enlite data url people developing pwd basically care logbook wise printout pretty good love changed management huge fan android iphone tech savvy talking helpful wow make sound benefit word point familiar apps flip phone make phone call fell lap question check smart phone free hmmmmm research today iphone gadget apple logo phone large screen compared flip phone thumb lot bought ebook reader scroll function work sold picked dawned thing heard people talking apps thought take phone link gave url log basically online version click free trial basic free free version long time satisfied bought version advantage version print log book send endo mandatory advantage happy pay check insulin pen insulin pump called rapid calc good link url track pump including insulin board iob check figwee swisschocolate mdi mysugr calculate iob thing work event pump mdi sound nice idea mysugr calculate iob techy flip phone transmitter receiver mail today saturday hooked buying iphone wanted bought greater accuracy guy talking apps enthusiasm buy fancy phone btw iphone lot funky gadget million thing talk monitor bgs trend news weather youtube instant message calculator contact info reminder list calendar clock timer camera basic thing iphone literally thousand thousand specialized apps buy free interested diabetic changed life creating mobile started thing learning reading nutrition information package people time diabetic read information important information developing help creating grocery list purchasing grocery store apps electronic version pen paper theory diabetic advertise obtain beta tester make people life start company main mission people respectfullyashley cribb founder lythouse lab llc lythouselabs',
#  'iphone android apps healthline click link suggestion',
#  'start logging blood glucose reading endo email weekly wondering couple glucose buddy simplicity limited chart layout complex junk enter food water exercise insulin ect blood glucose logging pay android good track pretty simple gonna shot interested mysugr downloaded interesting briefly loathe logging rely pump cgm track stuff worked lose food effort shave tracking macronutrient ratio yell pigging work myfitnesspal food increment work pay version purport offer logging cheap buy loathe logging meter touch verio sync touch reveal receives result meter bluetooth log automatically send blood glucose value doctor pump cgm combo send data stored device doctor glooko great syncs popular meter decent food diary count carbs feature faxing report joselin glooko issue omnipod supposedly working blueloop mycareconnect interface friendly major benefit automatically alert wife tested alert text email configurable peace mind glucose buddy mysugr month easy kind fun mysugr junior version kid track bgs developed apps glucosurfer org project calculates insulin board modern pump bolus calculator documentation menstrual cycle included anonymity free financed donation strong project analysis sharing capability',
nutshell time today post picture work upload carelink data scratch upload picture spinny wheel joy time charm ended url inserted link finally worked site happy uploading file server heard talk jdrf conference march immediately started tidepool blip love dexcom sensor reading carelink material site great drbb maureenh taryn mollyschreiber marieb feedback coming love hear experience blip tidepool uploader help make nutshell beta hope tidepool booth bay area summit attended yesterday university california san francisco medical center awesome hippa compliant forward dexcom charted anima pump information month thought follow view nutshell fun playing making note blip note taking insulin prebolusing percentage dual wave info eventually tracked nutshell perfect tool figuring tackle favorite meal tricky high fat require insulin strategy started blip tidepool updater love free url recommend taking insulin device upload data fromdexcomg mac windowsinsuletomnipod mac windowstandemtslim tflex tslim tslim mac windowsmedtronicparadigm enlite sensor mac window carelink login info pull data thereanimasping vibe mac windowsbayercontour contour usb contour link contour usb mac windowsabbottprecision xtra freestyle lite freedom lite windowsonetouchverioiq mac windowsi blip run google chrome browser chrome computer free url data window set chart amazingly endocrinologist think tight control low improve hour chart noticed pattern high late afternoon drop basal rate tweaked basal tiny bit window obvious pump setting cgm reading tidepool blip note phone fast easy ate pizza tubing kinked blip note automagically drop note chart reading time platform open source data remain accessible locked manufacturer web page criticismtidepool customize chart target range target range time window organize display info differently way chart handy ideal glad finally wrangled madness separate manufacturer sequestering data separate apps place huge',
#  'site endorse analysis software recommend feel good ultimate goal predictive statistic exist analysis pull data basal bolus testing compare exist minimed carelink upload software super analytical help identify trend time period number recently usb upload device buy minimed educator extra happy discovering graph meter display plugged web based site diasend diasend carelink analyze pump data history mm5 pump cgm pretty good job predicting high low event shortly happen extra time correct drift pump target range stop high low reduces severity prob injected vein rossen barbanov google android market import spreadsheet calculates insulin board statistic including standard deviation program ratio sensitivity update couple day founder glucosurfer project analysis tool offer valuablethe agp diagram show hour day highest volatility reminds development aware higher frequency dawn phenomenon put finger hurt inoffensive trend show relation category high high normal low developed month month act early warning tool sooner blood test pat shoulder recent improvement brain bag jellybeans smarties carry eat turn pump run high pretty tight standard couple day row turning pump medtronic carelink software super lazy talking online buddy evening suggested device sound alley',
#  'group people interested related smart phone web based application development giving feedback developer make people agreatchance folk working improve life great people joining inas emily mentioned application modd mobile detective feel free test user account create minute question feel free post comment reach personally lena mamykinadbmi columbia forward hearing everybodythank shared experience feedback mobile detective learned making address comment love hear time application url experience create account research project mean share user information lena allquick announcement released version application problem solving number feature notably possibility recommendation leave comment experience goal feel free create account url hear experience lena',
#  'nan called modd advice sickness plan pointless sick concerned proper nutrition busy throw ate brat aka diabetic unfriendly diet khrtmodd stand mobile detective mobile play create account interaction user phone feel free good point sickness plan advice comment research team comingthank lena lena test set account fictitious blood sugar reading tomorrow day pop check frequently consistently alarm alert turned omnipod pump pdm extremely beep weary hope cell phone start yelling test blood sugar testing blood sugar implies fail prefer check blood sugar claregreat creating account test account generally speaking modd sends reminder day optional choose set alert check blood glucose time day sound turn reminder click page edit profile password uncheck usage reminder check box main number setting goal day worth number frequency important click number average row table follow step love hear good catch checking testing lena completed day entry entered bunch spurious number response turned reminder start thing day graph bit dexcom day trend chart easy read interpret low number breakfast reading test work setting goal target range modified people perfectly happy meal prefer set target chose set goal breakfast reading disappointed choice offered increased dicreased spelled insulin increase dicrease discussing healthcare team discus time change phone ended putting suggestion presented applied situation doubt make general generalized suggest running spell check launching clairthank comment interesting point target changing target range determine target range stable change time timein term dicreased catch professional copy editor content health communication expert guess slipped crack corrected recommendation hoping team educator discussion educator clinician agree good general recommendation add general list recommendation recommendation thought interesting appropriatethanks comment lena read recommendation novice year rule standard treatment hypoglycemia carbs started counted suggested check glucose tablet figure carbs contained amusing hard pressed glucose tablet contained gram carbs gram called diachieve online problem rule consideration hypoglycemic patient treat hypo differently treat gram carbs increase blood sugar point glucose tablet increase point treat gram carbs increase point focus avoiding roller coaster treating hypoglycemia thing amusing goal section researching breakfast low suggestion drink alcohol suppose potential reason post breakfast hypoglycemia gawd wait noon target blood sugar insulin pump target range meal meal stable change set approval endo cde recommendation protein meal avoid drop started putting peanut butter toast morning smoothed post breakfast blood sugar basically good average pwd stick ada guideline access cde endos thing work improve control graphic image blood sugar necessarily day accurately represent trend decision making day worth data cgm making care clare clareah apology confusion misspelled annoying insightful comment year surprising recommendation glad hear generally application targeting individual experienced knowledgable lot learn recommend member tudiabetes make keeping track meal thatas additional note preparing version application social feature profile comment make friend tudiabetes couple week love wellthank lena houston problem lenai entering data modd couple week finally set goal inventing bunch breakfast low suggested adding protein breakfast make sense digested slowly smooth drop added protein breakfast thing smoothed mark problem solved breakfast blood sugar average normal solve problem high breakfast solve problem low breakfast guess day average set goal fix low report fixed goal average blood sugar lower helpful guess single day enter data time gather take day glucose average trend problem approach change behavior insulin dose diet exercise combination thing take longer day ass change routine adding protein breakfast changing pump setting basal rate ratio week declaring success failu ...
#  'vienna austria startup mysugr awarded million medium budget germany largest mass medium company mysugr place venture pitch day vpd competition focusing health fitness company mysugr cmo anton kittelberger explained company stay true mission making suck contest held noah conference berlin june featured familiar name runtastic meedoc place winner withings pitch anton explain mysugr make people happier healthier digital health solution make feel good taking care anton kittelberger cmo mysugr people ignore risktheir health prize improve countless life fear ofdiabetes therapy mysugr world idea real life destigmatizeit prosiebensat groupthe prosiebensat group largest independent medium corporation europe germany largest internet video company reach million household day station germany austria switzerland info url mysugrfounded people mysugr creates digital health solution people product characterized intelligent combination design technology medical expertise focused mysugr logbook registered user worldwide info url url johnson scott johnsonmysugr',
#  'group researcher department biomedical informatics columbia university developed application management application combination interactive website text message application individual track blood glucose reading based reading application individual recognize problematic pattern blood glucose behavior contribute pattern make personalized recommendation management behavior interested eligible study chance application make discovery hope study design tool management interested taking study link connect study website register stress participation voluntary membership tudiabetes community affected choice study detectiveif additional question contactlena mamykina assistant professor columbia university omcumc columbia study approved tudiabetes administration team',
#  'allthe creator called docto asked feedback docto purport knowledge based designed deliver medical advice based user distinct biometrics docto docto store mailing askdocto member tudiabetes test share opinion post discussion thread happy testing email heard huh touch clare emily clare amir developer docto talked url',
#  'good enter bloodsugar thing mysugr fun url pump track data pump computer waist recently posted basically question url holger glucosurfer insulet screwed shipment injecting holiday wait shipment pod arrive today simply pump actual pump bolus wizard stuff calculating correction carb bolus amount track iob biggest win make true pump mdi reality shocked competing apps track iob bolus wizard assist glucosurfer complete ton additional helpful feature finally purchasing glucosurfer android help support holger glucosurfer site encourage support contributes lot tud additional donation directly glucosurfer site encouraged',
#  'american association educator created called goal tracker aim people identify achieve health related goal healthy eating remembering medication coping stress free download android iphone search store aade goal tracker chance post comment address aspect taking care person diabetic physical health mental health taking time meditation diabetic benefiting part explore initial thought love reminds check thing view goal expedient page great everyday',
#  'sanofi bgstar agamatrix rebranded software compatible window install bit window installation roll sidiary url commercial software euro yearly download diabetic device data bgstar requires bgstar software installed discovered sidiary requires cable driver cable usual usb cable silabs chip link silabs doc driver download downloaded driver link click tool tab file cpxvcpwindows zip unzipped running exe installer modified slabvcp inf file adding identification string sanofi cable usbvidf pidaaaa window ultimate bit download bgstar reading merge glucometer brand sync online android sidiary good attach modified inf file replace original running exe install window recognise driver valid signed driver changed file remember trust driver exists linux osx software implement bgstar agamatrix protocol download slabvcp inf technology read entire post understand word starting talking meter talking software meter sanofi bgstar agamatrix url run window bit modified driver software url window bit user download analyze reading sidiary told checked method add modified driver list supported meter link garidan workaround install bgstar software bit window computer problem relates bit device driver bgstar setup wizard ended prematurely error standard compatibility setting run admin',
#  'called diary sinple easy mail log csv format open excel minor formatting send doctor love space track protein fat tag formula easy enter symlin note application author mention work progress adding feature feedback warrant make nan nan',
#  'triple complete happy announce called glucosurfer published apple store release offer apps iphone ipod android window phone manage glucosurfer diary feature insulin pump integrated bolus wizard calculation insulin board iob mdi user feature hope make daily management task easier visit website url group detail downloaded regardsholgerand team glucosurfer org today free edition glucosurfer iphone published store edition feature version test long buy experience negative glucosurfer group',
#  'lot glucose tracking info logging website accompanying iphone apps make entering data easier preferably necessarily free accompanying blackberry apps glucosurfer project online solution glucose log test blackberry simulator worked idea glucosurfer feel create link url browser line break url link user password admit minimalistic approach feedback highly appreciated send comment interesting solution slow daily prefer browser display small time load page zoom kind time consuming annoying browser understand curiosity needed zoom glucosurfer page open link kari blackberry good tracking ended buying itouch iphone apps work lack ability add info needed stuck duplicating info hard copy endo prefers hard copy versus downloading meter reading guess stuck keeping track fashion good luck search great shout kari necesarily database online store data blackberry device apps url free written nokian working blackberry url free data saved csv format send mail download open practically portable pda mobile device desktop computerif data stored online profile solution purposed holger purpose free version sugarstats url support opera mini install blackberry good luck finding solution sweetjimmy zoom page issue issue website developer web site include specific meta tag control zooming adjustment hope issue beautiful looked irecordit',
#  'started searching enables record track info relevant management track enter time day insulin dose carbs specific food eat important glycemic index food mysteriously affect differently5 exercise note illness stressi phone apple macbook air fine suggestion greatly appreciated lose midst switching myfitnesspal started hanging online exercise group fun share separately pump cgm job logging glucosurfer graphic representation thing timeline people scott johnson mysugr good result briefly hyper testing huge hassle stuff log mysugr iphone easy kind fun group url discussion apps url include integrate mentioned blackberry guy download hope wrong hand join iphone universe track monitor link glucosurfer org nice job integrating checked neat foodwise total sucker barcode scanning holger member communicative issue fixed glooko promise cool startup graps data meter forward android url record info note open spreadsheet excel organized column completely flexible take time enter info figure mysterious pattern happy recording insulin meter touch ultra smart remember enter insulin insulin usage statistic watch change tdd bolus basal ratio fact meter record listed carb exercise note time enter number specific food eaten',
#  'starting summer platform tudiabetes run start undergoing update make site easier simplify site layout improve work multiple device connection upcoming platform tuanalyze longer compatible tudiabetes coincides end year grant center disease control cdc develop tuanalyze taking july offer tremendous community tudiabetes org estudiabetes org participation research member tudiabetes community participated project donated data centerpiece peer reviewed scientific paper value care pattern hypoglycemia numerous abstract conference presentation forward working hand foundation identify way tudiabetes community contribute valuable cutting edge research information detail decommissioning tuanalyze additional question comment email study team tuanalyzechip org faqswhat happen data tuanalyzeafter july data entered tuanalyze including value survey response longer viewable tudiabetes download entered data secure server boston childrens hospital shut server data remain secureyes tuanalyze server shut data set maintained secure password protected computer boston childrens hospital accessible tuanalyze study team data enter tuanalyze stored randomized numberonce destroy link number identity tudiabetes effectively anonymizing data set chosen display acs entered tuanalyze tudiabetes profilewill upno data entered tuanalyze longer visible tudiabetes org update data downyes encourage add latest tuanalyze july final data set tudiabetes member complete survey complete edit survey completed result tuanalyze projectbelow set link result presented tuanalyze update community additional paper published early result blog poststhe state tuanalyze january flu vaccination tuanalyze participant compared national surveysearly result hypoglycemia surveyearly result device surveyjournal articlessharing data public health research member international online social networksurveillance online social network ass population level health status healthcare qualityparticipatory surveillance hypoglycemia harm online social network man total bummer love map scorecard recommend make source code github geek time motivation revive project api changed helpful specific problem habe solved integrate ning tudiabetes dhf payed project grand copyright source code problem',
#  'darios management solution incorporates regionally localized food database manage sugar levelscaesarea israel april labstyle innovation corp otcqbdrio developer dario management solution today announced partnership world leading global nutrition data application fatsecret fatsecret platform integrated darios powerful management software application deliver localized nutrition datasets generic food branded product restaurant item empower people easily track manage food intake resulting blood sugar insulin level dario user labstyles initial market location united kingdom italy zealand benefit immediately labstyle forward helping people thrive dario reach location europe year pending regulatory approval north america fatsecret dario management regionally localized food database tool help people automatically log sugar range food language country world fatsecret nutritional information carbohydrate fat content broad range food type information combined darios tool expected showing user food consumed affect individual fatsecret delighted partner dario seamlessly integrate world food nutrition tool dario empowering people charge health manage lenny moses founder fatsecret logging managing blood sugar level critical activity manage calculate required insulin treatment daily challenge people explained erez raphael president chief executive officer labstyle excited partner fatsecret add extensive food information database offering providing access critical food information user making easier people manage erez continued seeking make dario comprehensive added management solution initial feedback dario initial roll promising fatsecret travelling easier carbohydrate fat content basic local food bread coffee restaurant meal vary world dario people local food familiar impact sugar level dario user simply log blood sugar level recorded small stylish dario glucose meter plug directly smartphone user glucose meter manually insert blood sugar level recorded existing device simple prompt user note food eaten fatsecret library recent physical activity mood stress level dario automatically log data people sugar change manage condition treatment labstyle innovationslabstyle innovation corp otcqbdrio develops commercializes patent pending technology providing consumer laboratory testing capability smart mobile device labstyle flagship product dario personalized smart meter dario received mark certification september began world rollout select country december labstyle filed premarket notification application food drug administration fda dario smart meter dario blood glucose monitoring december labstyle pursuing patent application multiple area covering specific process related blood glucose level measurement general method rapid test body fluid mobile device cloud based service information url url note forward statementsthis news release statement representative partner labstyle innovation corp company related thereto forward statement meaning private security litigation reform act statement statement historical fact deemed forward statement limiting generality foregoing word plan project potential seek expect anticipate intend estimate continue intended identify forward statement reader cautioned important factor affect company actual result result differ materially forward statement news release factor affect company result include limited regulatory approval product demand market acceptance impact competitive product price product development commercialization technological difficulty success failure negotiation trade legal social economic risk risk adequacy existing cash resource additional factor contribute difference company actual result forward statement include limited risk discussed company filing security exchange commission reader cautioned actual result including limitation result integration fatsecret dario platform market acceptance company regulatory plan dario generally differ significantly set forward statement company undertakes ...
#  'recommendation android apps diabetic log food journal enter actual food item description carbs calorie question pal awesome great logging feature report syncs secure website grant doctor access generate print chart report pdf geek chart graph mysugr easy fun forgot provide linkdiabetes pal awesome check initially apps looked great unavailable android',
#  'desperate healthengage software mac software mac input reading computer create graph chart doctor internet insane software similar idea mac software read onetouch ultrasmart meter insurance company cover touch stripsemblemhealth stop exists solution touch ultra smart meter uploaded diasend diasend platform agnostic web based site produce nice chart integrates insulin pump continuous glucose monitor data diasend free data stored program meter reading stored date time stamp good luck touch ultra smart store record diasend work',
#  'mytherapy germany leading people manage medication taking mytherapy international level mytherapy uniquely combine medication reminder health tracking reliably reminds med active track vitals work mytherapy translates therapy simple list daily goal checking task peace mind time mytherapys built health journal summarizes medication intake health related information mytherapy free charge google play store apple store feature glance medication reminder patient disease med summary blood pressure blood sugar tracking wellbeing symptom monthly health report friend family motivate med free charge google play store url store url positive effect medication adherence scientifically proven charit berlin registration needed data protection hand individual based information party homepage url',
# ...
#  'developing helper team helparound thousand stranger stepping learned fear user cope realize imperative hold people trust time distress built alert simple pressing big red button shaking phone alert conference people trust designed community living caring risk experiencing physical emotional distress asthma attack severe allergic reaction addiction relapse panic attack dementia related confusion crohn flare ups list moment fine motor skill deteriorate thinking muddled make difficult properly navigate smartphone easy shake phone send alert alert download android mobile phone post approved hand foundation tudiabetes administrative staff imagine advanced dementia midst confusion clarity mind shake phone geez low bad dementia apps phone phone thought finding carbs sitting low faint feeling brilliant idea smartwatch user needed remind drink water respond watch hangout message frickin remind drink water sigh kid overload mind twitter tweeting ado dad smart alert deal smart phone convinced buy week returned remember operate concentrate phone function ignore feature brain deal dementia age memory problem abstraction smart phone fine dumb phone laptop complex task replacing component dlp dementia apps smartphone hard imagine agree mum lost banking ability forced passbook account card atm major problem buy electric kettle work switch slightly place dementia preferential losing physical ability imagine imprisoned wheelchair keen mind shake smartphone time life needed handle low helped moment alert zombie coffeeshop sat began people noticed figure wrong managed hard lot easier access emergency contact speak moment lucky people worked coffeeshop knew',
#  'apps site safe complaint specifically apps apps offered ning ning approved party developer ning platform tudiabetes created ning strict privacy policy addition ning requires party developer adhere separate strict privacy policy apps access profile picture name picture friend access email date birth policy prohibits apps collecting disclosing information permission apps information permission information decline absolutely safe application work crash browser hope helpful apps knew cell phone smart phone resolutely refuse doc social medium button word hash tag mouth meseriously privacy left protect excited angry bird expressing excitement brian list apps includes thing availability domain name brazil everyday gotta list domain name brazil everydayoh run thing resort playing angry bird video game shoot bit sarcasm brighten day hmmm missed sarcasm missed guess nicer sarcasm directed culture twinge insanity imho nan',
setting medication sport exercise glucose setting add carbs eaten correctional med run high note temporary basal setting statistic graph chart excellent mail doctor set reminder iphone check work logbook manager level pretty accurate check date data key control sugar run react food exercise make intelligent decision control data input easy color coding level glance good control day pay attention diagnosed week mysugr helping handle process committed taming monster day row premium version count carbs myfitnesspal track carbs enter mysugr great incorporate info fitbit apple health apple health play nice fitbit kind annoying apps track progress count carbs eat meal carefully figure carb calculation meal stored insulin dose work meal calorie king website present nutrition info standard format recommend buying scale combined calorie king figure insulin dosing calorie king mobile relationship calorie king satisfied user eat small number meal carry scale record successful insulin dos tied meal logging data powerful method educate user input contribute blood glucose outcome prefer system collect data directly device hard log time miss data entry social distraction comply time pump favored diasend collected data pump basal bolus insulin number carbs consumed carb dosing meter cgm fitbit basal bolus mdi primarily depend dexcom clarity day standard day main feedback make adjustment congrats keeping eye data regina reward number act info people roll eye sort activity concerned minutia counterintuitive devote time minutia reward feeling habit take activity gift time restored real life regina yep feedback no ...
#  'discussion topic iphone apps url late forever ago technology termssince ton apps developed improved iphone google launched android operating growing crazy term adoption question manny tudiabetes posted question apps livestrong myplate blackberry general dees apps discussion people hassle entering data hmm manual data entry big pain limitation hopeful signal year wireless automatic data entry norm exception android phone ally ontrack log blood glucose blood pressure pulse weight medication food carbs loosely exercise manual export csv send file doctor office device analyze blood glucose range time day chronologically track weight blood pressure pulse carbs correlate free easy livestrong android pulled market reworking shortly ally checked added unlike mapmy includes mobile apps free premium paid member livestrong charge separately motivated search couple apps iphone wavesense downloaded insulin big thing manually enter data online apps weekly require manual entry stopped big deal breaker touch cord program import information doctor iphone program easy import number touch program send super happy forgetting print problem glucose worthless information information hand influencing number time date blood glucose activity level carbs rapid basal insulin note field communication onetouch iphone blood glucose maximum efford enter data digit rest information entered manually convenience software supporting onetouch wireless communication device drain battery contrast keeping manual log book digital information analysed rewarded effords smart phone yesterday interested data entry tedious improve thing bit phone pretty accurate calorie burnt info garmin gps gizmo running inconceiveable start miss throw accuracy fuhgeddabouditit nice medical industry realize utility data agree standard format software people analysis level guess reason blown software sort take edge cliff decrease report tomorrow glucose buddy food activity medtronics site upload export pump meter data combine send cde doctor step love export site reference cde mac ipad problem apps fda ipod iphone approved software platform doubt ipod consist ipod data viewing device layer risk disclaimer alleged meter agamatrix plugged ipod basically run attachment ipod data viewing device protect people realize risk point stifiling creative integrated solution make life easier stuff limbo day inventive past year avalible make good point jake apps iphone apps stuck log life favourite term data entry fewest tap enter data glucose buddy good free entering data bit cumbersome pilot data analysis integration food database desktop ultimately recording reading note blog livejournal stick help remain track number broken statistic graph quick convenient data meter pump add note needed switching onetouch ping pump hoping meter remote serve purpose online thing iphone great wise carbohydrate information nan newly diagnosed year daughter tech savy ipod touch called pilot log blood glucose carb count insulin trend bar graph stats send desk print out like cost dollar dissapointment cde read vertical horizontal record party make cable compatible bit window remember install partial solution install window virtual machine window bit piece puzzle compatible cable risk engineering company make cable differentbetter usb serial converter based ftdi chipset crappy prolific lifescan slightly expensive lifescans cable make freestyle cable url trouble report send cde younlike pilot free program good additional fee desktop versionthanks advance dan love hear people pilot added store imac nice desktop iphone version good comment free droid called ontrack customize quick add feature glucose food excercise med weight pulse hbac body fat edit info stored report graph customize card restore lost data export excel email research apps apps hear epic fail today fancy ontrack thinking interesting home work txt mrsacidrock turned phone morning data spaced work cut record keeping touch ultra meter bit gateway series mach ...
#  'published healthlineaugust national fact sheet percent american staggering time prediabetics fortunately managed combination proper medical care care word regular doctor visit patient diligent monitoring blood sugar taking medication insulin prescribed physician diet exercise regimen overwhelming apps developed manage favorite supplement existing physician supervised care click icon learn totally window phone ecosystem kind sad platform glucosurfer android testing phase latest version offline capability vizualization current phase menstrual cycle proud ontrack android recently started glucosurfer great entering past data bolus wizard default setting ratio correctly predicted high low experienced added bonus enter data phone browser share result live endo personally wave sense logbook meal glucose buddy bit interface user friendly wave sense intuitive love trend chart feature sanofi ibgstar download free meter meal carb counting comprehensive easy require internet score android free edition switch google play support project thinking phone smart phone hear people opinion apps ibgstar tracker motivational problem mysugr cool logfrog manager patient ibgstar wanna pay sign problem send print data table overlooking advice appreciated tool android device called advanced insulin advisor insulin bolus calculator take account active insulin remaining body set carbohydrate directly predefined meal database picture daily read ifrdesign free aia advisor helpful']

# %%
# generates index for each item in the corpora (in this case it's just rank) and I'll use this for scoring later
# ranks = []

# for i in range(0,len(titles)):
#     ranks.append(i+1)

# %% [markdown]
# This section is focused on defining some functions to manipulate the synopses. First, I load [NLTK's](http://www.nltk.org/) list of English stop words. [Stop words](http://en.wikipedia.org/wiki/Stop_words) are words like "a", "the", or "in" which don't convey significant meaning. I'm sure there are much better explanations of this out there.

# %%
# load nltk's English stopwords as variable called 'stopwords'
stopwords = nltk.corpus.stopwords.words('english')

# %% [markdown]
# Next I import the [Snowball Stemmer](http://snowball.tartarus.org/) which is actually part of NLTK. [Stemming](http://en.wikipedia.org/wiki/Stemming) is just the process of breaking a word down into its root.

# %%
# load nltk's SnowballStemmer as variabled 'stemmer'
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("english")

# %% [markdown]
# Below I define two functions:
#
# <ul>
# <li> *tokenize_and_stem*: tokenizes (splits the synopsis into a list of its respective words (or tokens) and also stems each token <li> *tokenize_only*: tokenizes the synopsis only
# </ul>
#
# I use both these functions to create a dictionary which becomes important in case I want to use stems for an algorithm, but later convert stems back to their full words for presentation purposes. Guess what, I do want to do that!

# %%
# here I define a tokenizer and stemmer which returns the set of stems in the text that it is passed

def tokenize_and_stem(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    stems = [stemmer.stem(t) for t in filtered_tokens]
    return stems


def tokenize_only(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word.lower() for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    return filtered_tokens

# %% [markdown]
# Below I use my stemming/tokenizing and tokenizing functions to iterate over the list of synopses to create two vocabularies: one stemmed and one only tokenized.

# %%
totalvocab_stemmed = []
totalvocab_tokenized = []
for i in synopses:
    allwords_stemmed = tokenize_and_stem(i)
    totalvocab_stemmed.extend(allwords_stemmed)
    
    allwords_tokenized = tokenize_only(i)
    totalvocab_tokenized.extend(allwords_tokenized)

# %% [markdown]
# Using these two lists, I create a pandas DataFrame with the stemmed vocabulary as the index and the tokenized words as the column. The benefit of this is it provides an efficient way to look up a stem and return a full token. The downside here is that stems to tokens are one to many: the stem 'run' could be associated with 'ran', 'runs', 'running', etc. For my purposes this is fine--I'm perfectly happy returning the first token associated with the stem I need to look up.

# %%
vocab_frame = pd.DataFrame({'words': totalvocab_tokenized}, index = totalvocab_stemmed)

# %%
vocab_frame.shape
vocab_frame.head(10)
# Out:
#                        words
# blackberri        blackberry
# url                      url
# heremayb           heremaybe
# url                      url
# specif              specific
# good                    good
# luckpost            luckpost
# work                    work
# myglucohealth  myglucohealth
# glucomet          glucometer

# %% [markdown]
# ## Tf-idf and document similarity

# %% [markdown]
# <img src='http://www.jiem.org/index.php/jiem/article/viewFile/293/252/2402' align='right' style="margin-left:10px">
#
# Here, I define term frequency-inverse document frequency (tf-idf) vectorizer parameters and then convert the *synopses* list into a tf-idf matrix.
#
# To get a Tf-idf matrix, first count word occurrences by document. This is transformed into a document-term matrix (dtm). This is also just called a term frequency matrix. An example of a dtm is here at right.
#
# Then apply the term frequency-inverse document frequency weighting: words that occur frequently within a document but not frequently within the corpus receive a higher weighting as these words are assumed to contain more meaning in relation to the document.
#
# A couple things to note about the parameters I define below:
#
# <ul>
# <li> max_df: this is the maximum frequency within the documents a given feature can have to be used in the tfi-idf matrix. If the term is in greater than 80% of the documents it probably cares little meanining (in the context of film synopses)
# <li> min_idf: this could be an integer (e.g. 5) and the term would have to be in at least 5 of the documents to be considered. Here I pass 0.2; the term must be in at least 20% of the document. I found that if I allowed a lower min_df I ended up basing clustering on names--for example "Michael" or "Tom" are names found in several of the movies and the synopses use these names frequently, but the names carry no real meaning.
# <li> ngram_range: this just means I'll look at unigrams, bigrams and trigrams. See [n-grams](http://en.wikipedia.org/wiki/N-gram)
# </ul>

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer(max_df=40, max_features=500,
                                 min_df=8, stop_words='english',
                                 use_idf=True, tokenizer=tokenize_only, ngram_range=(1,3))

# %time tfidf_matrix = tfidf_vectorizer.fit_transform(synopses)

print(tfidf_matrix.shape)

df = pd.DataFrame(tfidf_matrix.toarray(), columns=tfidf_vectorizer.get_feature_names())
df.to_csv('Diabetes_TFIDF_Vect.csv')
# Out:
# Wall time: 252 ms
# (45, 187)

# %% [markdown]
# terms is just a list of the features used in the tf-idf matrix. This is a vocabulary

# %%
terms = tfidf_vectorizer.get_feature_names()
terms
# Out:
# ['ability',
#  'access',
#  'account',
#  'active',
#  'activity',
#  'add',
#  'agree',
#  'android',
#  'apple',
#  'application',
#  'appreciated',
#  'apps',
#  'awesome',
#  'basal',
#  'based',
#  'basically',
#  'bit',
#  'blood',
#  'blood glucose',
#  'blood sugar',
#  'board',
#  'bolus',
#  'buddy',
#  'buy',
#  'called',
#  'carb',
#  'carbohydrate',
#  'carbs',
#  'care',
#  'cgm',
#  'change',
#  'chart',
#  'check',
#  'comment',
#  'company',
#  'computer',
#  'create',
#  'current',
#  'daily',
#  'data',
#  'database',
#  'date',
#  'day',
#  'developed',
#  'developer',
#  'device',
#  'display',
#  'doctor',
#  'download',
#  'downloaded',
#  'easier',
#  'easy',
#  'eat',
#  'email',
#  'endo',
#  'enter',
#  'event',
#  'exercise',
#  'experience',
#  'fat',
#  'feature',
#  'feedback',
#  'feel',
#  'finally',
#  'food',
#  'free',
#  'fun',
#  'glucose',
#  'glucosurfer',
#  'goal',
#  'good',
#  'google',
#  'graph',
#  'great',
#  'group',
#  'happy',
#  'health',
#  'hear',
#  'heard',
#  'help',
#  'helpful',
#  'high',
#  'hope',
#  'hour',
#  'idea',
#  'important',
#  'including',
#  'info',
#  'information',
#  'insulin',
#  'insulin board',
#  'iphone',
#  'issue',
#  'kind',
#  'level',
#  'life',
#  'link',
#  'list',
#  'log',
#  'logging',
#  'long',
#  'lot',
#  'love',
#  'low',
#  'make',
#  'making',
#  'management',
#  'meal',
#  'medical',
#  'medication',
#  'meter',
#  'mobile',
#  'month',
#  'mysugr',
#  'needed',
#  'nice',
#  'note',
#  'number',
#  'offer',
#  'online',
#  'open',
#  'people',
#  'phone',
#  'place',
#  'platform',
#  'play',
#  'point',
#  'post',
#  'pretty',
#  'problem',
#  'program',
#  'project',
#  'pump',
#  'question',
#  'range',
#  'ratio',
#  'read',
#  'reading',
#  'related',
#  'reminder',
#  'report',
#  'research',
#  'result',
#  'run',
#  'send',
#  'set',
#  'setting',
#  'share',
#  'simple',
#  'site',
#  'small',
#  'smart',
#  'software',
#  'specific',
#  'start',
#  'started',
#  'store',
#  'sugar',
#  'suggestion',
#  'support',
#  'taking',
#  'team',
#  'technology',
#  'test',
#  'testing',
#  'thing',
#  'thought',
#  'thread',
#  'time',
#  'time day',
#  'today',
#  'tool',
#  'track',
#  'tracking',
#  'tudiabetes',
#  'update',
#  'url',
#  'user',
#  'version',
#  'watch',
#  'web',
#  'website',
#  'week',
#  'window',
#  'work',
#  'working',
#  'year']

# %% [markdown]
# dist is defined as 1 - the cosine similarity of each document. Cosine similarity is measured against the tf-idf matrix and can be used to generate a measure of similarity between each document and the other documents in the corpus (each synopsis among the synopses). Subtracting it from 1 provides cosine distance which I will use for plotting on a euclidean (2-dimensional) plane.
#
# Note that with dist it is possible to evaluate the similarity of any two or more synopses.

# %%
from sklearn.metrics.pairwise import cosine_similarity
dist = 1 - cosine_similarity(tfidf_matrix)
dist
# Out:
# array([[  0.00000000e+00,   6.65740758e-01,   1.00000000e+00, ...,
#           8.00744262e-01,   7.66022414e-01,   8.38798954e-01],
#        [  6.65740758e-01,   0.00000000e+00,   6.98652657e-01, ...,
#           6.28263501e-01,   5.08464099e-01,   6.35131461e-01],
#        [  1.00000000e+00,   6.98652657e-01,   0.00000000e+00, ...,
#           9.02337302e-01,   7.68363762e-01,   8.53947161e-01],
#        ...,
#        [  8.00744262e-01,   6.28263501e-01,   9.02337302e-01, ...,
#          -2.22044605e-16,   3.84489333e-01,   5.41278702e-01],
#        [  7.66022414e-01,   5.08464099e-01,   7.68363762e-01, ...,
#           3.84489333e-01,   0.00000000e+00,   5.07418178e-01],
#        [  8.38798954e-01,   6.35131461e-01,   8.53947161e-01, ...,
#           5.41278702e-01,   5.07418178e-01,   0.00000000e+00]])

# %% [markdown]
# # K-means clustering

# %% [markdown]
# Now onto the fun part. Using the tf-idf matrix, you can run a slew of clustering algorithms to better understand the hidden structure within the synopses. I first chose [k-means](http://en.wikipedia.org/wiki/K-means_clustering). K-means initializes with a pre-determined number of clusters (I chose 5). Each observation is assigned to a cluster (cluster assignment) so as to minimize the within cluster sum of squares. Next, the mean of the clustered observations is calculated and used as the new cluster centroid. Then, observations are reassigned to clusters and  centroids recalculated in an iterative process until the algorithm reaches convergence.
#
# I found it took several runs for the algorithm to converge a global optimum as k-means is susceptible to reaching local optima.

# %%
from sklearn.cluster import KMeans

num_clusters = 8
km = KMeans(n_clusters=num_clusters)

# %time km.fit(tfidf_matrix)
clusters = km.labels_.tolist()
len(clusters)
# Out:
# Wall time: 127 ms
# 45

# %%
# from sklearn.externals import joblib

# #joblib.dump(km,  'doc_cluster.pkl')
# km = joblib.load('doc_cluster.pkl')
# clusters = km.labels_.tolist()

# %%
import pandas as pd

# films = { 'title': titles, 'rank': ranks, 'synopsis': synopses, 'cluster': clusters, 'genre': genres }

# frame = pd.DataFrame(films, index = [clusters] , columns = ['rank', 'title', 'cluster', 'genre'])
# frame.to_csv('films.csv')
indx=[i+1 for i in range(len(synopses))]
films = {  'Number': indx, 'Discussion': synopses, 'cluster': clusters }

frame = pd.DataFrame(films, index = [indx] , columns = ['Discussion', 'cluster'])
frame.to_csv('Discussion.csv')

# %%
frame['cluster'].value_counts()
# Out:
# 2    13
# 1     9
# 4     7
# 0     5
# 5     4
# 7     3
# 6     2
# 3     2
# Name: cluster, dtype: int64

# %%
# grouped = frame['rank'].groupby(frame['cluster'])
# grouped.mean()

# %%
# from __future__ import print_function


# from __future__ import print_function

print("Top terms per cluster:")
print()
#sort cluster centers by proximity to centroid
order_centroids = km.cluster_centers_.argsort()[:, ::-1] 
li=[]
for i in range(num_clusters):
    print("Cluster %d words:" % i, end='')
    
    for ind in order_centroids[i, :30]: #replace 6 with n words per cluster
        print(' %s' % vocab_frame.ix[terms[ind].split(' ')].values.tolist()[0][0], end=',')
        li.append(' %s' % vocab_frame.ix[terms[ind].split(' ')].values.tolist()[0][0])
    print('\n') #add whitespace
    print([i for i in li if i != ' nan']) #add whitespace
    
#     print("Cluster %d titles:" % i, end='')
#     for title in frame.ix[i]['title'].values.tolist():
#         print(' %s,' % title, end='')
    print() #add whitespace
    print() #add whitespace
    li=[]
    
print()
print()
# Out:
# Top terms per cluster:
#
# Cluster 0 words: blood, nan, sugar, nan, program, blood, result, nan, blood, food, time, nan, user, nan, nan, support, data, nan, nan, level, nan, nan, make, nan, free, nan, feedback, small, month, nan,
#
# [' blood', ' sugar', ' program', ' blood', ' result', ' blood', ' food', ' time', ' user', ' support', ' data', ' level', ' make', ' free', ' feedback', ' small', ' month']
#
#
# Cluster 1 words: nan, data, pump, day, nan, time, url, window, research, bit, high, number, meter, low, chart, cgm, site, insulin, graph, tool, link, nan, set, nan, playing, make, nan, nan, good, downloaded,
#
# [' data', ' pump', ' day', ' time', ' url', ' window', ' research', ' bit', ' high', ' number', ' meter', ' low', ' chart', ' cgm', ' site', ' insulin', ' graph', ' tool', ' link', ' set', ' playing', ' make', ' good', ' downloaded']
#
#
# Cluster 2 words: insulin, food, log, mysugr, meter, nan, enter, data, nan, android, nan, nan, version, track, free, note, nan, great, report, nan, doctor, work, phone, nan, nan, time, love, send, url, carbs,
#
# [' insulin', ' food', ' log', ' mysugr', ' meter', ' enter', ' data', ' android', ' version', ' track', ' free', ' note', ' great', ' report', ' doctor', ' work', ' phone', ' time', ' love', ' send', ' url', ' carbs']
#
#
# Cluster 3 words: nan, pump, bolus, nan, group, track, today, url, store, nan, site, support, nan, insulin, make, android, easier, nan, window, buying, nan, insulin, board, nan, nan, team, nan, nan, nan, nan,
#
# [' pump', ' bolus', ' group', ' track', ' today', ' url', ' store', ' site', ' support', ' insulin', ' make', ' android', ' easier', ' window', ' buying', ' insulin', ' board', ' team']
#
#
# Cluster 4 words: phone, url, nan, nan, check, mysugr, smart, thing, point, nan, life, nan, list, nan, nan, health, comment, question, user, nan, free, account, make, thought, feel, work, nan, accessible, version, buying,
#
# [' phone', ' url', ' check', ' mysugr', ' smart', ' thing', ' point', ' life', ' list', ' health', ' comment', ' question', ' user', ' free', ' account', ' make', ' thought', ' feel', ' work', ' accessible', ' version', ' buying']
#
#
# Cluster 5 words: nan, store, health, goal, nan, post, thread, nan, nan, nan, playing, point, free, nan, url, downloaded, nan, time, nan, heard, nan, nan, email, sharing, nan, nan, nan, nan, test, feedback,
#
# [' store', ' health', ' goal', ' post', ' thread', ' playing', ' point', ' free', ' url', ' downloaded', ' time', ' heard', ' email', ' sharing', ' test', ' feedback']
#
#
# Cluster 6 words: watch, phone, data, android, nan, sharing, time, nan, date, nan, display, hour, cgm, nan, nan, site, day, user, group, nan, run, set, good, nan, nan, nan, start, bit, question, smart,
#
# [' watch', ' phone', ' data', ' android', ' sharing', ' time', ' date', ' display', ' hour', ' cgm', ' site', ' day', ' user', ' group', ' run', ' set', ' good', ' start', ' bit', ' question', ' smart']
#
#
# Cluster 7 words: nan, android, nan, link, nan, nan, list, nan, cgm, nan, data, url, nan, nan, food, idea, thread, program, start, carbs, love, track, nan, nan, good, user, make, nan, nan, fat,
#
# [' android', ' link', ' list', ' cgm', ' data', ' url', ' food', ' idea', ' thread', ' program', ' start', ' carbs', ' love', ' track', ' good', ' user', ' make', ' fat']

# %%
# #This is purely to help export tables to html and to correct for my 0 start rank (so that Godfather is 1, not 0)
# frame['Rank'] = frame['rank'] 
# frame['Title'] = frame['title']

# %%
#export tables to HTML
# print(frame[['Rank', 'Title','cluster']].loc[frame['cluster'] == 3].to_html(index=False))

# %% [markdown]
# # Multidimensional scaling

# %% [markdown]
# Here is some code to convert the dist matrix into a 2-dimensional array using multidimensional scaling. I won't pretend I know a ton about MDS, but it was useful for this purpose. Another option would be to use principal component analysis.

# %%
import os  # for os.path.basename

import matplotlib.pyplot as plt
import matplotlib as mpl

from sklearn.manifold import MDS

MDS()

# two components as we're plotting points in a two-dimensional plane
# "precomputed" because we provide a distance matrix
# we will also specify `random_state` so the plot is reproducible.
mds = MDS(n_components=2, dissimilarity="precomputed", random_state=1)

pos = mds.fit_transform(dist)  # shape (n_components, n_samples)

xs, ys = pos[:, 0], pos[:, 1]
print()

# %%
#strip any proper nouns (NNP) or plural proper nouns (NNPS) from a text
# from nltk.tag import pos_tag

# def strip_proppers_POS(text):
#     tagged = pos_tag(text.split()) #use NLTK's part of speech tagger
#     non_propernouns = [word for word,pos in tagged if pos != 'NNP' and pos != 'NNPS']
#     return non_propernouns

# %% [markdown]
# ## Visualizing document clusters

# %% [markdown]
# In this section, I demonstrate how you can visualize the document clustering output using matplotlib and mpld3 (a matplotlib wrapper for D3.js).
#
# First I define some dictionaries for going from cluster number to color and to cluster name. I based the cluster names off the words that were closest to each cluster centroid.

# %%
#set up colors per clusters using a dict
cluster_colors = {0: '#1b9e77', 1: '#d95f02', 2: '#7570b3', 3: '#e7298a', 4: '#66affe',5: '#aaffaa', 6: '#7ff0b3', 7: '#eee98a'}

#set up cluster names using a dict
cluster_names = {0: 'Cluster 1', 
                 1: 'Cluster 2', 
                 2: 'Cluster 3', 
                 3: 'Cluster 4',
                 4: 'Cluster 5', 
                 5: 'Cluster 6', 
                 6: 'Cluster 7', 
                 7: 'Cluster 8'}

# %% [markdown]
# Next, I plot the labeled observations (films, film titles) colored by cluster using matplotlib. I won't get into too much detail about the matplotlib plot, but I tried to provide some helpful commenting.

# %%
# %matplotlib inline

# %%
#create data frame that has the result of the MDS plus the cluster numbers and titles
df = pd.DataFrame(dict(x=xs, y=ys, label=clusters, title=indx)) 

#group by cluster
groups = df.groupby('label')


# set up plot
fig, ax = plt.subplots(figsize=(17, 9)) # set size
ax.margins(0.05) # Optional, just adds 5% padding to the autoscaling

#iterate through groups to layer the plot
#note that I use the cluster_name and cluster_color dicts with the 'name' lookup to return the appropriate color/label
for name, group in groups:
    ax.plot(group.x, group.y, marker='o', linestyle='', ms=12, label=cluster_names[name], color=cluster_colors[name], mec='none')
    ax.set_aspect('auto')
    ax.tick_params(\
        axis= 'x',          # changes apply to the x-axis
        which='both',      # both major and minor ticks are affected
        bottom='off',      # ticks along the bottom edge are off
        top='off',         # ticks along the top edge are off
        labelbottom='off')
    ax.tick_params(\
        axis= 'y',         # changes apply to the y-axis
        which='both',      # both major and minor ticks are affected
        left='off',      # ticks along the bottom edge are off
        top='off',         # ticks along the top edge are off
        labelleft='off')
    
ax.legend(numpoints=1)  #show legend with only 1 point

#add label in x,y position with the label as the film title
for i in range(len(df)):
    ax.text(df.loc[i]['x'], df.loc[i]['y'], df.loc[i]['title'], size=8)  

    
    
plt.show() #show the plot

#uncomment the below to save the plot if need be
#plt.savefig('clusters_small_noaxes.png', dpi=200)

# %%
plt.close()

# %% [markdown]
# The clustering plot looks great, but it pains my eyes to see overlapping labels. Having some experience with [D3.js](http://d3js.org/) I knew one solution would be to use a browser based/javascript interactive. Fortunately, I recently stumbled upon [mpld3](https://mpld3.github.io/) a matplotlib wrapper for D3. Mpld3 basically let's you use matplotlib syntax to create web interactives. It has a really easy, high-level API for adding tooltips on mouse hover, which is what I am interested in.
#
# It also has some nice functionality for zooming and panning. The below javascript snippet basicaly defines a custom location for where the zoom/pan toggle resides. Don't worry about it too much and you actually don't need to use it, but it helped for formatting purposes when exporting to the web later. The only thing you might want to change is the x and y attr for the position of the toolbar.

# %%
#define custom toolbar location
class TopToolbar(mpld3.plugins.PluginBase):
    """Plugin for moving toolbar to top of figure"""

    JAVASCRIPT = """
    mpld3.register_plugin("toptoolbar", TopToolbar);
    TopToolbar.prototype = Object.create(mpld3.Plugin.prototype);
    TopToolbar.prototype.constructor = TopToolbar;
    function TopToolbar(fig, props){
        mpld3.Plugin.call(this, fig, props);
    };

    TopToolbar.prototype.draw = function(){
      // the toolbar svg doesn't exist
      // yet, so first draw it
      this.fig.toolbar.draw();

      // then change the y position to be
      // at the top of the figure
      this.fig.toolbar.toolbar.attr("x", 150);
      this.fig.toolbar.toolbar.attr("y", 400);

      // then remove the draw function,
      // so that it is not called again
      this.fig.toolbar.draw = function() {}
    }
    """
    def __init__(self):
        self.dict_ = {"type": "toptoolbar"}

# %% [markdown]
# Here is the actual creation of the interactive scatterplot. I won't go into much more detail about it since it's pretty much a straightforward copy of one of the mpld3 examples, though I use a pandas groupby to group by cluster, then iterate through the groups as I layer the scatterplot. Note that relative to doing this with raw D3, mpld3 is much simpler to integrate into your Python workflow. If you click around the rest of my website you'll see that I do love D3, but for basic interactives I will probably use mpld3 a lot going forward.
#
# Note that mpld3 lets you define some custom CSS, which I use to style the font, the axes, and the left margin on the figure.

# %%
#create data frame that has the result of the MDS plus the cluster numbers and titles
df = pd.DataFrame(dict(x=xs, y=ys, label=clusters, title=indx)) 

#group by cluster
groups = df.groupby('label')

#define custom css to format the font and to remove the axis labeling
css = """
text.mpld3-text, div.mpld3-tooltip {
  font-family:Arial, Helvetica, sans-serif;
}

g.mpld3-xaxis, g.mpld3-yaxis {
display: none; }
"""

# Plot 
fig, ax = plt.subplots(figsize=(14,6)) #set plot size
ax.margins(0.03) # Optional, just adds 5% padding to the autoscaling

#iterate through groups to layer the plot
#note that I use the cluster_name and cluster_color dicts with the 'name' lookup to return the appropriate color/label
for name, group in groups:
    points = ax.plot(group.x, group.y, marker='o', linestyle='', ms=18, label=cluster_names[name], mec='none', color=cluster_colors[name])
    ax.set_aspect('auto')
    labels = [i for i in group.title]
    
    #set tooltip using points, labels and the already defined 'css'
    tooltip = mpld3.plugins.PointHTMLTooltip(points[0], labels,
                                       voffset=10, hoffset=10, css=css)
    #connect tooltip to fig
    mpld3.plugins.connect(fig, tooltip, TopToolbar())    
    
    #set tick marks as blank
    ax.axes.get_xaxis().set_ticks([])
    ax.axes.get_yaxis().set_ticks([])
    
    #set axis as blank
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)

    
ax.legend(numpoints=1) #show legend with only one dot

mpld3.display() #show the plot

#uncomment the below to export to html
#html = mpld3.fig_to_html(fig)
#print(html)
# Out:
# <style>
#
# text.mpld3-text, div.mpld3-tooltip {
#   font-family:Arial, Helvetica, sans-serif;
# }
#
# g.mpld3-xaxis, g.mpld3-yaxis {
# display: none; }
#
# text.mpld3-text, div.mpld3-tooltip {
#   font-family:Arial, Helvetica, sans-serif;
# }
#
# g.mpld3-xaxis, g.mpld3-yaxis {
# display: none; }
#
# text.mpld3-text, div.mpld3-tooltip {
#   font-family:Arial, Helvetica, sans-serif;
# }
#
# g.mpld3-xaxis, g.mpld3-yaxis {
# display: none; }
#
# text.mpld3-text, div.mpld3-tooltip {
#   font-family:Arial, Helvetica, sans-serif;
# }
#
# g.mpld3-xaxis, g.mpld3-yaxis {
# display: none; }
#
# text.mpld3-text, div.mpld3-tooltip {
#   font-family:Arial, Helvetica, sans-serif;
# }
#
# g.mpld3-xaxis, g.mpld3-yaxis {
# display: none; }
#
# text.mpld3-text, div.mpld3-tooltip {
#   font-family:Arial, Helvetica, sans-serif;
# }
#
# g.mpld3-xaxis, g.mpld3-yaxis {
# display: none; }
#
# text.mpld3-text, div.mpld3-tooltip {
#   font-family:Arial, Helvetica, sans-serif;
# }
#
# g.mpld3-xaxis, g.mpld3-yaxis {
# display: none; }
#
# text.mpld3-text, div.mpld3-tooltip {
#   font-family:Arial, Helvetica, sans-serif;
# }
#
# g.mpld3-xaxis, g.mpld3-yaxis {
# display: none; }
#
# </style>
#
# <div id="fig_el338827917609650248799053211"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#     mpld3.register_plugin("htmltooltip", HtmlTooltipPlugin);
#     HtmlTooltipPlugin.prototype = Object.create(mpld3.Plugin.prototype);
#     HtmlTooltipPlugin.prototype.constructor = HtmlTooltipPlugin;
#     HtmlTooltipPlugin.prototype.requiredProps = ["id"];
#     HtmlTooltipPlugin.prototype.defaultProps = {labels:null,
#                                                 hoffset:0,
#                                                 voffset:10};
#     function HtmlTooltipPlugin(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     HtmlTooltipPlugin.prototype.draw = function(){
#        var obj = mpld3.get_element(this.props.id);
#        var labels = this.props.labels;
#        var tooltip = d3.select("body").append("div")
#                     .attr("class", "mpld3-tooltip")
#                     .style("position", "absolute")
#                     .style("z-index", "10")
#                     .style("visibility", "hidden");
#
#        obj.elements()
#            .on("mouseover", function(d, i){
#                               tooltip.html(labels[i])
#                                      .style("visibility", "visible");})
#            .on("mousemove", function(d, i){
#                   tooltip
#                     .style("top", d3.event.pageY + this.props.voffset + "px")
#                     .style("left",d3.event.pageX + this.props.hoffset + "px");
#                  }.bind(this))
#            .on("mouseout",  function(d, i){
#                            tooltip.style("visibility", "hidden");});
#     };
#
#     mpld3.register_plugin("toptoolbar", TopToolbar);
#     TopToolbar.prototype = Object.create(mpld3.Plugin.prototype);
#     TopToolbar.prototype.constructor = TopToolbar;
#     function TopToolbar(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     TopToolbar.prototype.draw = function(){
#       // the toolbar svg doesn't exist
#       // yet, so first draw it
#       this.fig.toolbar.draw();
#
#       // then change the y position to be
#       // at the top of the figure
#       this.fig.toolbar.toolbar.attr("x", 150);
#       this.fig.toolbar.toolbar.attr("y", 400);
#
#       // then remove the draw function,
#       // so that it is not called again
#       this.fig.toolbar.draw = function() {}
#     }
#
#     mpld3.register_plugin("htmltooltip", HtmlTooltipPlugin);
#     HtmlTooltipPlugin.prototype = Object.create(mpld3.Plugin.prototype);
#     HtmlTooltipPlugin.prototype.constructor = HtmlTooltipPlugin;
#     HtmlTooltipPlugin.prototype.requiredProps = ["id"];
#     HtmlTooltipPlugin.prototype.defaultProps = {labels:null,
#                                                 hoffset:0,
#                                                 voffset:10};
#     function HtmlTooltipPlugin(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     HtmlTooltipPlugin.prototype.draw = function(){
#        var obj = mpld3.get_element(this.props.id);
#        var labels = this.props.labels;
#        var tooltip = d3.select("body").append("div")
#                     .attr("class", "mpld3-tooltip")
#                     .style("position", "absolute")
#                     .style("z-index", "10")
#                     .style("visibility", "hidden");
#
#        obj.elements()
#            .on("mouseover", function(d, i){
#                               tooltip.html(labels[i])
#                                      .style("visibility", "visible");})
#            .on("mousemove", function(d, i){
#                   tooltip
#                     .style("top", d3.event.pageY + this.props.voffset + "px")
#                     .style("left",d3.event.pageX + this.props.hoffset + "px");
#                  }.bind(this))
#            .on("mouseout",  function(d, i){
#                            tooltip.style("visibility", "hidden");});
#     };
#
#     mpld3.register_plugin("toptoolbar", TopToolbar);
#     TopToolbar.prototype = Object.create(mpld3.Plugin.prototype);
#     TopToolbar.prototype.constructor = TopToolbar;
#     function TopToolbar(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     TopToolbar.prototype.draw = function(){
#       // the toolbar svg doesn't exist
#       // yet, so first draw it
#       this.fig.toolbar.draw();
#
#       // then change the y position to be
#       // at the top of the figure
#       this.fig.toolbar.toolbar.attr("x", 150);
#       this.fig.toolbar.toolbar.attr("y", 400);
#
#       // then remove the draw function,
#       // so that it is not called again
#       this.fig.toolbar.draw = function() {}
#     }
#
#     mpld3.register_plugin("htmltooltip", HtmlTooltipPlugin);
#     HtmlTooltipPlugin.prototype = Object.create(mpld3.Plugin.prototype);
#     HtmlTooltipPlugin.prototype.constructor = HtmlTooltipPlugin;
#     HtmlTooltipPlugin.prototype.requiredProps = ["id"];
#     HtmlTooltipPlugin.prototype.defaultProps = {labels:null,
#                                                 hoffset:0,
#                                                 voffset:10};
#     function HtmlTooltipPlugin(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     HtmlTooltipPlugin.prototype.draw = function(){
#        var obj = mpld3.get_element(this.props.id);
#        var labels = this.props.labels;
#        var tooltip = d3.select("body").append("div")
#                     .attr("class", "mpld3-tooltip")
#                     .style("position", "absolute")
#                     .style("z-index", "10")
#                     .style("visibility", "hidden");
#
#        obj.elements()
#            .on("mouseover", function(d, i){
#                               tooltip.html(labels[i])
#                                      .style("visibility", "visible");})
#            .on("mousemove", function(d, i){
#                   tooltip
#                     .style("top", d3.event.pageY + this.props.voffset + "px")
#                     .style("left",d3.event.pageX + this.props.hoffset + "px");
#                  }.bind(this))
#            .on("mouseout",  function(d, i){
#                            tooltip.style("visibility", "hidden");});
#     };
#
#     mpld3.register_plugin("toptoolbar", TopToolbar);
#     TopToolbar.prototype = Object.create(mpld3.Plugin.prototype);
#     TopToolbar.prototype.constructor = TopToolbar;
#     function TopToolbar(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     TopToolbar.prototype.draw = function(){
#       // the toolbar svg doesn't exist
#       // yet, so first draw it
#       this.fig.toolbar.draw();
#
#       // then change the y position to be
#       // at the top of the figure
#       this.

# %% [markdown]
# # Hierarchical document clustering

# %% [markdown]
# Now that I was successfuly able to cluster and plot the documents using k-means, I wanted to try another clustering algorithm. I chose the Ward clustering algorithm because it offers hierarchical clustering. Ward clustering is an agglomerative clustering method, meaning that at each stage, the pair of clusters with minimum between-cluster distance are merged. I used the precomputed cosine distance matrix (dist) to calclate a linkage_matrix, which I then plot as a dendrogram.
#
# Note that this method returned 3 primary clusters, with the largest cluster being split into about 4 major subclusters. Note that the cluster in red contains many of the "Killed, soldiers, captain" films. Braveheart and Gladiator are within the same low-level cluster which is interesting as these are probably my two favorite movies.

# %%
from scipy.cluster.hierarchy import ward, dendrogram

linkage_matrix = ward(dist) #define the linkage_matrix using ward clustering pre-computed distances

fig, ax = plt.subplots(figsize=(15, 20)) # set size
ax = dendrogram(linkage_matrix, orientation="right", labels=indx);

plt.tick_params(\
    axis= 'x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',         # ticks along the top edge are off
    labelbottom='off')

plt.tight_layout() #show plot with tight layout

#uncomment below to save figure
plt.savefig('ward_clusters.png', dpi=200) #save figure as ward_clusters

# %%
plt.close()

# %% [markdown]
# # Latent Dirichlet Allocation

# %% [markdown]
# This section focuses on using Latent Dirichlet Allocation (LDA) to learn yet more about the hidden structure within the top 100 film synopses. LDA is a probabilistic topic model that assumes documents are a mixture of topics and that each word in the document is attributable to the document's topics. There is quite a good high-level overview of probabilistic topic models by one of the big names in the field, David Blei, available in the Communications of the ACM here. Incidentally, Blei was one of the authors of the seminal paper on LDA.
#
# For my implementaiton of LDA, I use the Gensim pacakage. I'm going to preprocess the synopses a bit differently here, and first I define a function to remove any proper noun.

# %%
#strip any proper names from a text...unfortunately right now this is yanking the first word from a sentence too.
import string
def strip_proppers(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent) if word.islower()]
    return "".join([" "+i if not i.startswith("'") and i not in string.punctuation else i for i in tokens]).strip()

# %% [markdown]
# Since the above function is just based on capitalization, it is prone to remove words at the beginning of sentences. So, I wrote the below function using NLTK's part of speech tagger. However, it took way too long to run across all synopses, so I stuck with the above.

# %%
#strip any proper nouns (NNP) or plural proper nouns (NNPS) from a text
from nltk.tag import pos_tag

def strip_proppers_POS(text):
    tagged = pos_tag(text.split()) #use NLTK's part of speech tagger
    non_propernouns = [word for word,pos in tagged if pos != 'NNP' and pos != 'NNPS']
    return non_propernouns

# %% [markdown]
# Here I run the actual text processing (removing of proper nouns, tokenization, removal of stop words)

# %%
from gensim import corpora, models, similarities 

#remove proper names
# %time preprocess = [strip_proppers(doc) for doc in synopses]

#tokenize
# %time tokenized_text = [tokenize_and_stem(text) for text in preprocess]

#remove stop words
# %time texts = [[word for word in text if word not in stopwords] for text in tokenized_text]
# Out:
# Wall time: 117 ms
# Wall time: 428 ms
# Wall time: 42.1 ms

# %%
print(len([word for word in texts[0] if word not in stopwords]))
print(len(texts[0]))
# Out:
# 80
# 80

# %% [markdown]
# Below are some Gensim specific conversions; I also filter out extreme words (see inline comment)

# %%
#create a Gensim dictionary from the texts
dictionary = corpora.Dictionary(texts)

#remove extremes (similar to the min/max df step used when creating the tf-idf matrix)
dictionary.filter_extremes(no_below=1, no_above=0.8)

#convert the dictionary to a bag of words corpus for reference
corpus = [dictionary.doc2bow(text) for text in texts]

# %%
len(corpus)
# Out:
# 45

# %% [markdown]
# The actual model runs below. I took 100 passes to ensure convergence, but you can see that it took my machine 13 minutes to run. My chunksize is larger than the corpus so basically all synopses are used per pass. I should optimize this, and Gensim has the capacity to run in parallel. I'll likely explore this further as I use the implementation on larger corpora.

# %%
# %time lda = models.LdaModel(corpus, num_topics=5, id2word=dictionary, update_every=5, chunksize=10000, passes=100)
# Out:
# Wall time: 7.88 s

# %% [markdown]
# Each topic has a set of words that defines it, along with a certain probability.

# %%
lda.show_topics()
# Out:
# [(0,
#   '0.010*"mysugr" + 0.010*"data" + 0.009*"carb" + 0.009*"insulin" + 0.008*"phone" + 0.007*"log" + 0.007*"app" + 0.007*"work" + 0.007*"time" + 0.007*"food"'),
#  (1,
#   '0.035*"watch" + 0.029*"xdrip" + 0.025*"phone" + 0.018*"wear" + 0.016*"android" + 0.011*"dexcom" + 0.008*"connect" + 0.008*"direct" + 0.008*"collector" + 0.008*"receiv"'),
#  (2,
#   '0.014*"data" + 0.010*"time" + 0.008*"blood" + 0.008*"pump" + 0.008*"day" + 0.007*"carelink" + 0.007*"sugar" + 0.007*"url" + 0.006*"make" + 0.006*"insulin"'),
#  (3,
#   '0.011*"dario" + 0.011*"manag" + 0.011*"peopl" + 0.010*"educ" + 0.010*"drop" + 0.009*"food" + 0.008*"compani" + 0.007*"inform" + 0.006*"mobil" + 0.006*"program"'),
#  (4,
#   '0.016*"data" + 0.011*"meter" + 0.011*"glucos" + 0.009*"iphon" + 0.009*"log" + 0.008*"softwar" + 0.008*"app" + 0.008*"bit" + 0.008*"time" + 0.007*"window"')]

# %%
topics = lda.print_topics(5, num_words=20)
topics
# Out:
# [(0,
#   '0.010*"mysugr" + 0.010*"data" + 0.009*"carb" + 0.009*"insulin" + 0.008*"phone" + 0.007*"log" + 0.007*"app" + 0.007*"work" + 0.007*"time" + 0.007*"food" + 0.007*"day" + 0.006*"report" + 0.006*"enter" + 0.006*"version" + 0.006*"track" + 0.006*"thing" + 0.006*"love" + 0.005*"free" + 0.005*"make" + 0.005*"read"'),
#  (1,
#   '0.035*"watch" + 0.029*"xdrip" + 0.025*"phone" + 0.018*"wear" + 0.016*"android" + 0.011*"dexcom" + 0.008*"connect" + 0.008*"direct" + 0.008*"collector" + 0.008*"receiv" + 0.008*"work" + 0.007*"time" + 0.007*"run" + 0.007*"read" + 0.007*"set" + 0.006*"day" + 0.006*"data" + 0.006*"smartwatch" + 0.006*"transmitt" + 0.006*"devic"'),
#  (2,
#   '0.014*"data" + 0.010*"time" + 0.008*"blood" + 0.008*"pump" + 0.008*"day" + 0.007*"carelink" + 0.007*"sugar" + 0.007*"url" + 0.006*"make" + 0.006*"insulin" + 0.006*"predict" + 0.005*"glucos" + 0.005*"note" + 0.005*"upload" + 0.005*"cgm" + 0.005*"work" + 0.005*"free" + 0.004*"thing" + 0.004*"love" + 0.004*"graph"'),
#  (3,
#   '0.011*"dario" + 0.011*"manag" + 0.011*"peopl" + 0.010*"educ" + 0.010*"drop" + 0.009*"food" + 0.008*"compani" + 0.007*"inform" + 0.006*"mobil" + 0.006*"program" + 0.005*"statement" + 0.005*"user" + 0.005*"fatsecret" + 0.005*"app" + 0.005*"result" + 0.005*"forward" + 0.005*"expert" + 0.005*"labstyl" + 0.005*"sugar" + 0.005*"url"'),
#  (4,
#   '0.016*"data" + 0.011*"meter" + 0.011*"glucos" + 0.009*"iphon" + 0.009*"log" + 0.008*"softwar" + 0.008*"app" + 0.008*"bit" + 0.008*"time" + 0.007*"window" + 0.007*"track" + 0.007*"pump" + 0.007*"ontrack" + 0.007*"insulin" + 0.007*"free" + 0.006*"download" + 0.006*"android" + 0.006*"usb" + 0.005*"touch" + 0.005*"food"')]

# %% [markdown]
# Here, I convert the topics into just a list of the top 20 words in each topic. You can see a similar breakdown of topics as I identified using k-means including a war/family topic and a more clearly war/epic topic.

# %%
import re
topics_matrix = lda.show_topics(formatted=False, num_words=20)
topics_matrix = np.array(topics_matrix, dtype=object)

topic_words = topics_matrix[:,1]
for i in topic_words:
    print([  re.sub('[^a-zA-Z]+', '', str(word)) for word in i]) 
    print()
# Out:
# ['mysugr', 'data', 'carb', 'insulin', 'phone', 'log', 'app', 'work', 'time', 'food', 'day', 'report', 'enter', 'version', 'track', 'thing', 'love', 'free', 'make', 'read']
#
# ['watch', 'xdrip', 'phone', 'wear', 'android', 'dexcom', 'connect', 'direct', 'collector', 'receiv', 'work', 'time', 'run', 'read', 'set', 'day', 'data', 'smartwatch', 'transmitt', 'devic']
#
# ['data', 'time', 'blood', 'pump', 'day', 'carelink', 'sugar', 'url', 'make', 'insulin', 'predict', 'glucos', 'note', 'upload', 'cgm', 'work', 'free', 'thing', 'love', 'graph']
#
# ['dario', 'manag', 'peopl', 'educ', 'drop', 'food', 'compani', 'inform', 'mobil', 'program', 'statement', 'user', 'fatsecret', 'app', 'result', 'forward', 'expert', 'labstyl', 'sugar', 'url']
#
# ['data', 'meter', 'glucos', 'iphon', 'log', 'softwar', 'app', 'bit', 'time', 'window', 'track', 'pump', 'ontrack', 'insulin', 'free', 'download', 'android', 'usb', 'touch', 'food']
